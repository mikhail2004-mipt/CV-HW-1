# %%
"""
Простая CNN модель для классификации изображений.
Архитектура: 3 сверточных блока + классификатор.
"""

import torch
import torch.nn as nn
import torch.nn.functional as F


class SimpleCNN(nn.Module):
    """
    Простая сверточная нейронная сеть для классификации изображений.

    Архитектура:
    - 3 сверточных блока (Conv2d + BatchNorm + ReLU + MaxPool)
    - Adaptive Average Pooling для гибкости к размеру входа
    - Fully Connected классификатор с Dropout

    Args:
        num_classes: Количество классов для классификации
        dropout: Вероятность dropout (по умолчанию 0.5)
    """

    def __init__(self, num_classes: int, dropout: float = 0.5):
        super(SimpleCNN, self).__init__()

        # Первый сверточный блок: 3 -> 64 каналов
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Второй сверточный блок: 64 -> 128 каналов
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Третий сверточный блок: 128 -> 256 каналов
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        # Adaptive pooling для получения фиксированного размера
        self.adaptive_pool = nn.AdaptiveAvgPool2d((7, 7))

        # Fully connected слои
        self.fc1 = nn.Linear(256 * 7 * 7, 512)
        self.dropout = nn.Dropout(dropout)
        self.fc2 = nn.Linear(512, num_classes)

        # Инициализация весов
        self._initialize_weights()

    def _initialize_weights(self):
        """Инициализация весов модели (Kaiming initialization для ReLU)."""
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Прямой проход через сеть.

        Args:
            x: Входной тензор размера (batch_size, 3, H, W)

        Returns:
            Выходной тензор размера (batch_size, num_classes)
        """
        # Первый блок
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.pool1(x)

        # Второй блок
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.pool2(x)

        # Третий блок
        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.pool3(x)

        # Adaptive pooling
        x = self.adaptive_pool(x)

        # Flatten
        x = x.view(x.size(0), -1)

        # Fully connected слои
        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)

        return x

    def get_num_parameters(self) -> int:
        """Возвращает количество обучаемых параметров."""
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

# %%
"""
ViT-Tiny модель с linear probe для классификации изображений.
Использует предобученный backbone с замороженными весами.
"""

import torch
import torch.nn as nn
import timm
from typing import Optional


class ViTLinearProbe(nn.Module):
    """
    Vision Transformer Tiny с linear probe.

    Загружает предобученную ViT-Tiny модель, замораживает все слои backbone
    и обучает только линейную голову (classifier).

    Args:
        num_classes: Количество классов для классификации
        pretrained: Использовать ли предобученные веса (по умолчанию True)
        model_name: Название модели из timm (по умолчанию 'vit_tiny_patch16_224')
    """

    def __init__(
        self,
        num_classes: int,
        pretrained: bool = True,
        model_name: str = 'vit_tiny_patch16_224'
    ):
        super(ViTLinearProbe, self).__init__()

        # Загружаем предобученную ViT-Tiny модель
        self.backbone = timm.create_model(
            model_name,
            pretrained=pretrained,
            num_classes=0  # Убираем классификатор
        )

        # Замораживаем все параметры backbone
        for param in self.backbone.parameters():
            param.requires_grad = False

        # Получаем размерность выходных признаков
        self.feature_dim = self.backbone.num_features

        # Создаем новую линейную голову
        self.classifier = nn.Linear(self.feature_dim, num_classes)

        # Инициализация весов классификатора
        nn.init.normal_(self.classifier.weight, 0, 0.01)
        nn.init.constant_(self.classifier.bias, 0)

        print(f"ViT-Tiny модель загружена:")
        print(f"  - Модель: {model_name}")
        print(f"  - Предобучена: {pretrained}")
        print(f"  - Размерность признаков: {self.feature_dim}")
        print(f"  - Количество классов: {num_classes}")
        print(f"  - Backbone заморожен: все параметры requires_grad=False")

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Прямой проход через сеть.

        Args:
            x: Входной тензор размера (batch_size, 3, 224, 224)

        Returns:
            Выходной тензор размера (batch_size, num_classes)
        """
        # Извлекаем признаки через backbone (без градиентов)
        with torch.no_grad():
            features = self.backbone(x)

        # Классификация через линейную голову
        output = self.classifier(features)

        return output

    def unfreeze_backbone(self):
        """Размораживает backbone для fine-tuning (опционально)."""
        for param in self.backbone.parameters():
            param.requires_grad = True
        print("Backbone разморожен для fine-tuning")

    def get_num_parameters(self, trainable_only: bool = True) -> int:
        """
        Возвращает количество параметров.

        Args:
            trainable_only: Если True, считает только обучаемые параметры

        Returns:
            Количество параметров
        """
        if trainable_only:
            return sum(p.numel() for p in self.parameters() if p.requires_grad)
        else:
            return sum(p.numel() for p in self.parameters())

    def get_parameter_stats(self) -> dict:
        """Возвращает статистику по параметрам модели."""
        total_params = self.get_num_parameters(trainable_only=False)
        trainable_params = self.get_num_parameters(trainable_only=True)
        frozen_params = total_params - trainable_params

        return {
            'total': total_params,
            'trainable': trainable_params,
            'frozen': frozen_params,
            'trainable_percentage': (trainable_params / total_params) * 100
        }


class ViTLinearProbeWithDropout(ViTLinearProbe):
    """
    ViT-Tiny с linear probe и dropout для регуляризации.

    Args:
        num_classes: Количество классов для классификации
        pretrained: Использовать ли предобученные веса
        model_name: Название модели из timm
        dropout: Вероятность dropout перед классификатором
    """

    def __init__(
        self,
        num_classes: int,
        pretrained: bool = True,
        model_name: str = 'vit_tiny_patch16_224',
        dropout: float = 0.1
    ):
        super().__init__(num_classes, pretrained, model_name)

        # Заменяем простой классификатор на классификатор с dropout
        self.classifier = nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(self.feature_dim, num_classes)
        )

        # Инициализация весов
        for m in self.classifier.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

        print(f"  - Dropout: {dropout}")

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """Прямой проход с dropout."""
        # Извлекаем признаки через backbone (без градиентов)
        with torch.no_grad():
            features = self.backbone(x)

        # Классификация через голову с dropout
        output = self.classifier(features)

        return output

# %%
from torchvision.datasets import STL10
from pathlib import Path
import numpy as np

def export_stl10_to_imagefolder(
    root: Path,
    train_root: Path,
    val_root: Path,
    val_ratio: float = 0.2,
    max_per_class: Optional[int] = None,
    seed: int = 42
) -> None:
    """
    Export STL10 dataset to ImageFolder structure with train/val splits.

    Args:
        root: Root directory for the dataset
        val_ratio: Proportion of data to use for validation
        max_per_class: Maximum number of samples per class (None for all)
        seed: Random seed for reproducibility
    """

    # Load dataset
    ds = STL10(str(root), split='train', download=True)
    classes = list(ds.classes)

    # Create directory structure
    _create_class_directories(train_root, val_root, classes)

    # Process each class
    labels = np.array(ds.labels)

    for cls_idx, cls_name in enumerate(classes):
        # Get indices for current class
        cls_mask = labels == cls_idx
        cls_indices = np.where(cls_mask)[0]

        # Shuffle indices
        rng = np.random.default_rng(seed + cls_idx)
        rng.shuffle(cls_indices)

        # Limit samples if specified
        if max_per_class is not None:
            cls_indices = cls_indices[:max_per_class]

        # Split into train and validation
        n_val = int(round(len(cls_indices) * val_ratio))
        val_indices = cls_indices[:n_val]
        train_indices = cls_indices[n_val:]

        # Save images
        _save_images(ds, train_root / cls_name, train_indices)
        _save_images(ds, val_root / cls_name, val_indices)


def _create_class_directories(train_root: Path, val_root: Path, classes: list) -> None:
    """Create directory structure for all classes."""
    for cls_name in classes:
        (train_root / cls_name).mkdir(parents=True, exist_ok=True)
        (val_root / cls_name).mkdir(parents=True, exist_ok=True)


def _save_images(dataset, output_dir: Path, indices: np.ndarray) -> None:
    """Save images from dataset to output directory."""
    for idx in indices:
        output_path = output_dir / f'{idx:06d}.png'
        if not output_path.exists():
            img, _ = dataset[int(idx)]
            img.save(output_path)

# %%
"""
Модуль для подготовки данных и аугментаций.
Реализует загрузку датасета в формате ImageFolder с аугментациями.
"""

import torch
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms
import random
import numpy as np
from typing import Tuple, Optional


def set_seed(seed: int = 42):
    """
    Устанавливает фиксированный seed для воспроизводимости результатов.

    Args:
        seed: Значение seed для генераторов случайных чисел
    """
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def get_transforms(train: bool = True) -> transforms.Compose:
    """
    Возвращает композицию трансформаций для обучающей или валидационной выборки.

    Args:
        train: Если True, применяются аугментации для обучения

    Returns:
        Композиция трансформаций
    """
    # Нормализация ImageNet (стандартные значения для предобученных моделей)
    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )

    if train:
        # Аугментации для обучающей выборки
        return transforms.Compose([
            transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
            transforms.ToTensor(),
            normalize
        ])
    else:
        # Трансформации для валидационной выборки (без аугментаций)
        return transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            normalize
        ])


def get_dataloaders(
    data_dir: str,
    batch_size: int = 32,
    num_workers: int = 4,
    seed: int = 42
) -> Tuple[DataLoader, DataLoader, int]:
    """
    Создает DataLoader'ы для обучающей и валидационной выборок.

    Args:
        data_dir: Путь к директории с данными (должна содержать train/ и val/)
        batch_size: Размер батча
        num_workers: Количество процессов для загрузки данных
        seed: Seed для воспроизводимости

    Returns:
        Кортеж (train_loader, val_loader, num_classes)
    """
    set_seed(seed)

    # Создаем датасеты с соответствующими трансформациями
    train_dataset = datasets.ImageFolder(
        root=f"{data_dir}/train",
        transform=get_transforms(train=True)
    )

    val_dataset = datasets.ImageFolder(
        root=f"{data_dir}/val",
        transform=get_transforms(train=False)
    )

    num_classes = len(train_dataset.classes)

    print(f"Загружен датасет:")
    print(f"  - Классы: {train_dataset.classes}")
    print(f"  - Количество классов: {num_classes}")
    print(f"  - Обучающая выборка: {len(train_dataset)} изображений")
    print(f"  - Валидационная выборка: {len(val_dataset)} изображений")

    # Создаем DataLoader'ы
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        pin_memory=True,
        drop_last=True  # Для стабильности batch normalization
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=True
    )

    return train_loader, val_loader, num_classes


def get_sanity_check_loader(
    data_dir: str,
    num_batches: int = 5,
    batch_size: int = 32,
    seed: int = 42
) -> Tuple[DataLoader, int]:
    """
    Создает DataLoader для sanity check (overfit на нескольких батчах).

    Args:
        data_dir: Путь к директории с данными
        num_batches: Количество батчей для overfit
        batch_size: Размер батча
        seed: Seed для воспроизводимости

    Returns:
        Кортеж (sanity_loader, num_classes)
    """
    set_seed(seed)

    # Загружаем полный датасет
    train_dataset = datasets.ImageFolder(
        root=f"{data_dir}/train",
        transform=get_transforms(train=True)
    )

    num_classes = len(train_dataset.classes)

    # Берем только первые num_batches * batch_size примеров
    num_samples = num_batches * batch_size
    indices = list(range(min(num_samples, len(train_dataset))))

    subset = Subset(train_dataset, indices)

    print(f"Sanity check режим:")
    print(f"  - Количество примеров: {len(subset)}")
    print(f"  - Количество батчей: {num_batches}")
    print(f"  - Размер батча: {batch_size}")

    # Создаем DataLoader (shuffle=True для разнообразия)
    sanity_loader = DataLoader(
        subset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        drop_last=True
    )

    return sanity_loader, num_classes


def verify_dataset(data_dir: str) -> bool:
    """
    Проверяет корректность структуры датасета.

    Args:
        data_dir: Путь к директории с данными

    Returns:
        True если датасет корректен, иначе False
    """
    import os

    train_dir = os.path.join(data_dir, 'train')
    val_dir = os.path.join(data_dir, 'val')

    if not os.path.exists(train_dir):
        print(f"Ошибка: директория {train_dir} не найдена")
        return False

    if not os.path.exists(val_dir):
        print(f"Ошибка: директория {val_dir} не найдена")
        return False

    # Проверяем количество классов
    train_classes = [d for d in os.listdir(train_dir)
                     if os.path.isdir(os.path.join(train_dir, d))]
    val_classes = [d for d in os.listdir(val_dir)
                   if os.path.isdir(os.path.join(val_dir, d))]

    if len(train_classes) < 5:
        print(f"Ошибка: недостаточно классов в train ({len(train_classes)} < 5)")
        return False

    if set(train_classes) != set(val_classes):
        print("Предупреждение: классы в train и val не совпадают")

    # Проверяем количество изображений в каждом классе
    for class_name in train_classes:
        class_dir = os.path.join(train_dir, class_name)
        num_images = len([f for f in os.listdir(class_dir)
                         if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
        if num_images < 100:
            print(f"Предупреждение: класс {class_name} содержит только {num_images} изображений (< 100)")

    print("Датасет прошел базовую проверку")
    return True


from pathlib import Path
from torchvision.datasets import STL10, ImageFolder

DIR_PATH = Path("./data")
DIR_PATH.mkdir(exist_ok=True)

TRAIN_ROOT = DIR_PATH / 'train'
TRAIN_ROOT.mkdir(exist_ok=True)
VAL_ROOT = DIR_PATH / 'val'
VAL_ROOT.mkdir(exist_ok=True)

export_stl10_to_imagefolder(DIR_PATH, TRAIN_ROOT, VAL_ROOT)

# Проверяем датасет
if verify_dataset(DIR_PATH):
    # Создаем DataLoader'ы для проверки
    train_loader, val_loader, num_classes = get_dataloaders(
        str(DIR_PATH),
        batch_size=4,
        num_workers=2
    )

    # Проверяем первый батч
    images, labels = next(iter(train_loader))
    print(f"\nПример батча:")
    print(f"  - Размер изображений: {images.shape}")
    print(f"  - Размер меток: {labels.shape}")
    print(f"  - Метки в батче: {labels.tolist()}")
# Out:
# 100%|██████████| 2.64G/2.64G [00:43<00:00, 61.2MB/s]
# Датасет прошел базовую проверку
# Загружен датасет:
#   - Классы: ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
#   - Количество классов: 10
#   - Обучающая выборка: 4000 изображений
#   - Валидационная выборка: 1000 изображений
#
# Пример батча:
#   - Размер изображений: torch.Size([4, 3, 224, 224])
#   - Размер меток: torch.Size([4])
#   - Метки в батче: [2, 9, 2, 0]

# %%
#import shutil
#folder_path = './data'
#shutil.rmtree(folder_path)

# %%
"""
Тренировочный цикл для CNN и ViT-Tiny моделей.
Включает sanity checks, логирование в TensorBoard, сохранение чекпоинтов.
"""

import os
import time

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm

def train_epoch(
    model: nn.Module,
    train_loader,
    criterion,
    optimizer,
    device: torch.device,
    epoch: int,
    writer: SummaryWriter,
    global_step: int
) -> tuple:
    """
    Обучение модели на одной эпохе.

    Args:
        model: Модель для обучения
        train_loader: DataLoader с обучающими данными
        criterion: Функция потерь
        optimizer: Оптимизатор
        device: Устройство (CPU/GPU)
        epoch: Номер текущей эпохи
        writer: TensorBoard writer
        global_step: Глобальный шаг для логирования

    Returns:
        Кортеж (средний loss, accuracy, новый global_step)
    """
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    pbar = tqdm(train_loader, desc=f'Epoch {epoch} [Train]')

    for batch_idx, (images, labels) in enumerate(pbar):
        images, labels = images.to(device), labels.to(device)

        # Прямой проход
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Обратный проход
        loss.backward()
        optimizer.step()

        # Статистика
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

        # Логирование в TensorBoard
        if batch_idx % 10 == 0:
            writer.add_scalar('Train/Loss_step', loss.item(), global_step)
            writer.add_scalar('Train/Accuracy_step', 100. * correct / total, global_step)
            writer.add_scalar('Train/LR', optimizer.param_groups[0]['lr'], global_step)

        global_step += 1

        # Обновление progress bar
        pbar.set_postfix({
            'loss': f'{running_loss / (batch_idx + 1):.4f}',
            'acc': f'{100. * correct / total:.2f}%'
        })

    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100. * correct / total

    return epoch_loss, epoch_acc, global_step


def validate(
    model: nn.Module,
    val_loader,
    criterion,
    device: torch.device,
    epoch: int,
    writer: SummaryWriter
) -> tuple:
    """
    Валидация модели.

    Args:
        model: Модель для валидации
        val_loader: DataLoader с валидационными данными
        criterion: Функция потерь
        device: Устройство (CPU/GPU)
        epoch: Номер текущей эпохи
        writer: TensorBoard writer

    Returns:
        Кортеж (средний loss, accuracy)
    """
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        pbar = tqdm(val_loader, desc=f'Epoch {epoch} [Val]')

        for images, labels in pbar:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            pbar.set_postfix({
                'loss': f'{running_loss / (pbar.n + 1):.4f}',
                'acc': f'{100. * correct / total:.2f}%'
            })

    epoch_loss = running_loss / len(val_loader)
    epoch_acc = 100. * correct / total

    return epoch_loss, epoch_acc


def log_model_weights_and_gradients(
    model: nn.Module,
    writer: SummaryWriter,
    epoch: int
):
    """
    Логирование гистограмм весов и градиентов в TensorBoard.

    Args:
        model: Модель
        writer: TensorBoard writer
        epoch: Номер эпохи
    """
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Логируем веса
            writer.add_histogram(f'Weights/{name}', param.data, epoch)

            # Логируем градиенты (если есть)
            if param.grad is not None:
                writer.add_histogram(f'Gradients/{name}', param.grad, epoch)


def sanity_check(
    model: nn.Module,
    sanity_loader,
    criterion,
    optimizer,
    device: torch.device,
    num_epochs: int,
    writer: SummaryWriter
):
    """
    Sanity check: overfit на нескольких батчах.
    Модель должна достичь ~100% accuracy на этих данных.

    Args:
        model: Модель для проверки
        sanity_loader: DataLoader с небольшим количеством данных
        criterion: Функция потерь
        optimizer: Оптимизатор
        device: Устройство
        num_epochs: Количество эпох для overfit
        writer: TensorBoard writer
    """
    print("\n" + "="*60)
    print("SANITY CHECK: Overfit на нескольких батчах")
    print("="*60)

    model.train()
    global_step = 0

    for epoch in range(1, num_epochs + 1):
        running_loss = 0.0
        correct = 0
        total = 0

        for batch_idx, (images, labels) in enumerate(sanity_loader):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

            global_step += 1

        epoch_loss = running_loss / len(sanity_loader)
        epoch_acc = 100. * correct / total

        # Логирование
        writer.add_scalar('SanityCheck/Loss', epoch_loss, epoch)
        writer.add_scalar('SanityCheck/Accuracy', epoch_acc, epoch)

        if epoch % 10 == 0 or epoch == 1:
            print(f"Epoch {epoch}/{num_epochs} - Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.2f}%")

        # Если достигли 100% accuracy, sanity check пройден
        if epoch_acc >= 99.9:
            print(f"\n✓ Sanity check ПРОЙДЕН на эпохе {epoch}!")
            print(f"  Модель достигла {epoch_acc:.2f}% accuracy на обучающих данных")
            break
    else:
        print(f"\n✗ Sanity check НЕ ПРОЙДЕН!")
        print(f"  Финальная accuracy: {epoch_acc:.2f}% (ожидалось ~100%)")
        print(f"  Возможные проблемы: слишком маленький learning rate, ошибки в модели")


def train_model(
    model_name, data_dir, epochs, batch_size, lr, seed, num_workers, sanity_check_bool, num_batches
):
    """
    Основная функция обучения модели.

    Args:
        args: Аргументы командной строки
    """
    # Установка seed для воспроизводимости
    set_seed(seed)

    # Устройство
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Используется устройство: {device}")

    # Создание директорий
    os.makedirs('checkpoints', exist_ok=True)
    os.makedirs('runs', exist_ok=True)

    # TensorBoard writer
    run_name = f"{model_name}_{time.strftime('%Y%m%d_%H%M%S')}"
    if sanity_check_bool:
        run_name += "_sanity"
    writer = SummaryWriter(f'runs/{run_name}')

    # Загрузка данных
    if sanity_check_bool:
        print("\nРежим: SANITY CHECK")
        train_loader, num_classes = get_sanity_check_loader(
            data_dir,
            num_batches=num_batches,
            batch_size=batch_size,
            seed=seed
        )
        val_loader = None
    else:
        print("\nРежим: ОБЫЧНОЕ ОБУЧЕНИЕ")
        train_loader, val_loader, num_classes = get_dataloaders(
            data_dir,
            batch_size=batch_size,
            num_workers=num_workers,
            seed=seed
        )

    # Создание модели
    print(f"\nСоздание модели: {model_name}")
    if model_name == 'cnn':
        model = SimpleCNN(num_classes=num_classes, dropout=0.5)
    elif model_name == 'vit':
        model = ViTLinearProbe(num_classes=num_classes, pretrained=True)
    else:
        raise ValueError(f"Неизвестная модель: {model_name}")

    model = model.to(device)

    # Вывод информации о модели
    if hasattr(model, 'get_num_parameters'):
        num_params = model.get_num_parameters()
        print(f"Количество обучаемых параметров: {num_params:,}")

    if hasattr(model, 'get_parameter_stats'):
        stats = model.get_parameter_stats()
        print(f"Статистика параметров:")
        print(f"  - Всего: {stats['total']:,}")
        print(f"  - Обучаемых: {stats['trainable']:,}")
        print(f"  - Замороженных: {stats['frozen']:,}")

    # Функция потерь
    criterion = nn.CrossEntropyLoss()

    # Оптимизатор
    if model_name == 'cnn':
        optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    else:  # ViT
        optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=1e-4)

    # Learning rate scheduler
    scheduler = CosineAnnealingLR(optimizer, T_max=epochs)

    # Sanity check
    if sanity_check_bool:
        sanity_check(
            model, train_loader, criterion, optimizer,
            device, epochs, writer
        )
        writer.close()
        return

    # Обучение
    print(f"\nНачало обучения на {epochs} эпох")
    print("="*60)

    best_val_acc = 0.0
    global_step = 0

    for epoch in range(1, epochs + 1):
        # Обучение
        train_loss, train_acc, global_step = train_epoch(
            model, train_loader, criterion, optimizer,
            device, epoch, writer, global_step
        )

        # Валидация
        val_loss, val_acc = validate(
            model, val_loader, criterion, device, epoch, writer
        )

        # Обновление learning rate
        scheduler.step()

        # Логирование эпохи
        writer.add_scalar('Epoch/Train_Loss', train_loss, epoch)
        writer.add_scalar('Epoch/Train_Accuracy', train_acc, epoch)
        writer.add_scalar('Epoch/Val_Loss', val_loss, epoch)
        writer.add_scalar('Epoch/Val_Accuracy', val_acc, epoch)
        writer.add_scalar('Epoch/LR', optimizer.param_groups[0]['lr'], epoch)

        # Логирование весов и градиентов (каждые 5 эпох)
        if epoch % 5 == 0:
            log_model_weights_and_gradients(model, writer, epoch)

        print(f"\nEpoch {epoch}/{epochs}:")
        print(f"  Train - Loss: {train_loss:.4f}, Acc: {train_acc:.2f}%")
        print(f"  Val   - Loss: {val_loss:.4f}, Acc: {val_acc:.2f}%")
        print(f"  LR: {optimizer.param_groups[0]['lr']:.6f}")

        # Сохранение лучшей модели
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            checkpoint_path = f'checkpoints/{model_name}_best.pth'
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_acc': val_acc,
                'val_loss': val_loss,
            }, checkpoint_path)
            print(f"  ✓ Сохранена лучшая модель (val_acc: {val_acc:.2f}%)")

        print("-" * 60)

    # Сохранение финальной модели
    final_checkpoint_path = f'checkpoints/{model_name}_final.pth'
    torch.save({
        'epoch': epochs,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'val_acc': val_acc,
        'val_loss': val_loss,
    }, final_checkpoint_path)

    print("\n" + "="*60)
    print("Обучение завершено!")
    print(f"Лучшая val accuracy: {best_val_acc:.2f}%")
    print(f"Финальная val accuracy: {val_acc:.2f}%")
    print(f"Модели сохранены в директории 'checkpoints/'")
    print(f"Логи TensorBoard: runs/{run_name}")
    print("="*60)

    writer.close()

# %%
model = 'cnn'
lr = 0.001

# Запуск обучения
train_model(model, DIR_PATH, 20, 32, lr, 42, 4, False, 5)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Используется устройство: cuda
#
# Режим: ОБЫЧНОЕ ОБУЧЕНИЕ
# Загружен датасет:
#   - Классы: ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
#   - Количество классов: 10
#   - Обучающая выборка: 4000 изображений
#   - Валидационная выборка: 1000 изображений
#
# Создание модели: cnn
# Количество обучаемых параметров: 6,799,882
#
# Начало обучения на 20 эпох
# ============================================================
# Epoch 1 [Train]: 100%|██████████| 125/125 [00:22<00:00,  5.59it/s, loss=2.0242, acc=26.05%]
# Epoch 1 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.54it/s, loss=1.8902, acc=34.20%]
# Epoch 1/20:
#   Train - Loss: 2.0242, Acc: 26.05%
#   Val   - Loss: 1.7721, Acc: 34.20%
#   LR: 0.000994
#   ✓ Сохранена лучшая модель (val_acc: 34.20%)
# ------------------------------------------------------------
# Epoch 2 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.30it/s, loss=1.7994, acc=31.77%]
# Epoch 2 [Val]: 100%|██████████| 32/32 [00:03<00:00, 10.00it/s, loss=1.6575, acc=36.80%]
# Epoch 2/20:
#   Train - Loss: 1.7994, Acc: 31.77%
#   Val   - Loss: 1.6575, Acc: 36.80%
#   LR: 0.000976
#   ✓ Сохранена лучшая модель (val_acc: 36.80%)
# ------------------------------------------------------------
# Epoch 3 [Train]: 100%|██████████| 125/125 [00:21<00:00,  5.82it/s, loss=1.6919, acc=35.67%]
# Epoch 3 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.96it/s, loss=1.6450, acc=39.10%]
# Epoch 3/20:
#   Train - Loss: 1.6919, Acc: 35.67%
#   Val   - Loss: 1.5422, Acc: 39.10%
#   LR: 0.000946
#   ✓ Сохранена лучшая модель (val_acc: 39.10%)
# ------------------------------------------------------------
# Epoch 4 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.41it/s, loss=1.6445, acc=37.48%]
# Epoch 4 [Val]: 100%|██████████| 32/32 [00:03<00:00,  9.90it/s, loss=1.6091, acc=41.10%]
# Epoch 4/20:
#   Train - Loss: 1.6445, Acc: 37.48%
#   Val   - Loss: 1.5085, Acc: 41.10%
#   LR: 0.000905
#   ✓ Сохранена лучшая модель (val_acc: 41.10%)
# ------------------------------------------------------------
# Epoch 5 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.27it/s, loss=1.5887, acc=39.48%]
# Epoch 5 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.61it/s, loss=1.5441, acc=44.40%]
# Epoch 5/20:
#   Train - Loss: 1.5887, Acc: 39.48%
#   Val   - Loss: 1.4476, Acc: 44.40%
#   LR: 0.000854
#   ✓ Сохранена лучшая модель (val_acc: 44.40%)
# ------------------------------------------------------------
# Epoch 6 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.02it/s, loss=1.5238, acc=43.75%]
# Epoch 6 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.37it/s, loss=1.4169, acc=51.30%]
# Epoch 6/20:
#   Train - Loss: 1.5238, Acc: 43.75%
#   Val   - Loss: 1.3726, Acc: 51.30%
#   LR: 0.000794
#   ✓ Сохранена лучшая модель (val_acc: 51.30%)
# ------------------------------------------------------------
# Epoch 7 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.07it/s, loss=1.4664, acc=45.00%]
# Epoch 7 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.76it/s, loss=1.4336, acc=47.60%]
# Epoch 7/20:
#   Train - Loss: 1.4664, Acc: 45.00%
#   Val   - Loss: 1.3888, Acc: 47.60%
#   LR: 0.000727
# ------------------------------------------------------------
# Epoch 8 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.37it/s, loss=1.4240, acc=46.52%]
# Epoch 8 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.48it/s, loss=1.3704, acc=51.50%]
# Epoch 8/20:
#   Train - Loss: 1.4240, Acc: 46.52%
#   Val   - Loss: 1.3704, Acc: 51.50%
#   LR: 0.000655
#   ✓ Сохранена лучшая модель (val_acc: 51.50%)
# ------------------------------------------------------------
# Epoch 9 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.36it/s, loss=1.3832, acc=48.02%]
# Epoch 9 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.48it/s, loss=1.3417, acc=51.10%]
# Epoch 9/20:
#   Train - Loss: 1.3832, Acc: 48.02%
#   Val   - Loss: 1.2997, Acc: 51.10%
#   LR: 0.000578
# ------------------------------------------------------------
# Epoch 10 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.02it/s, loss=1.3399, acc=48.80%]
# Epoch 10 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.55it/s, loss=1.3162, acc=54.00%]
# Epoch 10/20:
#   Train - Loss: 1.3399, Acc: 48.80%
#   Val   - Loss: 1.2751, Acc: 54.00%
#   LR: 0.000500
#   ✓ Сохранена лучшая модель (val_acc: 54.00%)
# ------------------------------------------------------------
# Epoch 11 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.07it/s, loss=1.2981, acc=51.08%]
# Epoch 11 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.67it/s, loss=1.3372, acc=50.70%]
# Epoch 11/20:
#   Train - Loss: 1.2981, Acc: 51.08%
#   Val   - Loss: 1.2954, Acc: 50.70%
#   LR: 0.000422
# ------------------------------------------------------------
# Epoch 12 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.25it/s, loss=1.2513, acc=54.25%]
# Epoch 12 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.36it/s, loss=1.2147, acc=55.30%]
# Epoch 12/20:
#   Train - Loss: 1.2513, Acc: 54.25%
#   Val   - Loss: 1.2147, Acc: 55.30%
#   LR: 0.000345
#   ✓ Сохранена лучшая модель (val_acc: 55.30%)
# ------------------------------------------------------------
# Epoch 13 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.38it/s, loss=1.1977, acc=55.05%]
# Epoch 13 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.65it/s, loss=1.1918, acc=56.80%]
# Epoch 13/20:
#   Train - Loss: 1.1977, Acc: 55.05%
#   Val   - Loss: 1.1918, Acc: 56.80%
#   LR: 0.000273
#   ✓ Сохранена лучшая модель (val_acc: 56.80%)
# ------------------------------------------------------------
# Epoch 14 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.35it/s, loss=1.1700, acc=56.33%]
# Epoch 14 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.54it/s, loss=1.2493, acc=57.80%]
# Epoch 14/20:
#   Train - Loss: 1.1700, Acc: 56.33%
#   Val   - Loss: 1.1712, Acc: 57.80%
#   LR: 0.000206
#   ✓ Сохранена лучшая модель (val_acc: 57.80%)
# ------------------------------------------------------------
# Epoch 15 [Train]: 100%|██████████| 125/125 [00:20<00:00,  5.98it/s, loss=1.1435, acc=58.17%]
# Epoch 15 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.66it/s, loss=1.1793, acc=58.20%]
# Epoch 15/20:
#   Train - Loss: 1.1435, Acc: 58.17%
#   Val   - Loss: 1.1424, Acc: 58.20%
#   LR: 0.000146
#   ✓ Сохранена лучшая модель (val_acc: 58.20%)
# ------------------------------------------------------------
# Epoch 16 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.05it/s, loss=1.1157, acc=59.40%]
# Epoch 16 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.42it/s, loss=1.1484, acc=59.90%]
# Epoch 16/20:
#   Train - Loss: 1.1157, Acc: 59.40%
#   Val   - Loss: 1.1125, Acc: 59.90%
#   LR: 0.000095
#   ✓ Сохранена лучшая модель (val_acc: 59.90%)
# ------------------------------------------------------------
# Epoch 17 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.17it/s, loss=1.0949, acc=59.23%]
# Epoch 17 [Val]: 100%|██████████| 32/32 [00:03<00:00, 10.53it/s, loss=1.1269, acc=61.20%]
# Epoch 17/20:
#   Train - Loss: 1.0949, Acc: 59.23%
#   Val   - Loss: 1.0917, Acc: 61.20%
#   LR: 0.000054
#   ✓ Сохранена лучшая модель (val_acc: 61.20%)
# ------------------------------------------------------------
# Epoch 18 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.30it/s, loss=1.0490, acc=61.02%]
# Epoch 18 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.41it/s, loss=1.0956, acc=60.00%]
# Epoch 18/20:
#   Train - Loss: 1.0490, Acc: 61.02%
#   Val   - Loss: 1.0956, Acc: 60.00%
#   LR: 0.000024
# ------------------------------------------------------------
# Epoch 19 [Train]: 100%|██████████| 125/125 [00:19<00:00,  6.28it/s, loss=1.0434, acc=61.05%]
# Epoch 19 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.17it/s, loss=1.1555, acc=61.80%]
# Epoch 19/20:
#   Train - Loss: 1.0434, Acc: 61.05%
#   Val   - Loss: 1.0833, Acc: 61.80%
#   LR: 0.000006
#   ✓ Сохранена лучшая модель (val_acc: 61.80%)
# ------------------------------------------------------------
# Epoch 20 [Train]: 100%|██████████| 125/125 [00:20<00:00,  6.02it/s, loss=1.0513, acc=60.92%]
# Epoch 20 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.51it/s, loss=1.1575, acc=61.60%]
# Epoch 20/20:
#   Train - Loss: 1.0513, Acc: 60.92%
#   Val   - Loss: 1.0851, Acc: 61.60%
#   LR: 0.000000
# ------------------------------------------------------------
#
# ============================================================
# Обучение завершено!
# Лучшая val accuracy: 61.80%
# Финальная val accuracy: 61.60%
# Модели сохранены в директории 'checkpoints/'
# Логи TensorBoard: runs/cnn_20251229_041244
# ============================================================

# %%
model = 'vit'
lr = 0.01

# Запуск обучения
train_model(model, DIR_PATH, 20, 32, lr, 42, 4, False, 5)
# Out:
# Используется устройство: cuda
#
# Режим: ОБЫЧНОЕ ОБУЧЕНИЕ
# Загружен датасет:
#   - Классы: ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
#   - Количество классов: 10
#   - Обучающая выборка: 4000 изображений
#   - Валидационная выборка: 1000 изображений
#
# Создание модели: vit
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/22.9M [00:00<?, ?B/s]
# ViT-Tiny модель загружена:
#   - Модель: vit_tiny_patch16_224
#   - Предобучена: True
#   - Размерность признаков: 192
#   - Количество классов: 10
#   - Backbone заморожен: все параметры requires_grad=False
# Количество обучаемых параметров: 1,930
# Статистика параметров:
#   - Всего: 5,526,346
#   - Обучаемых: 1,930
#   - Замороженных: 5,524,416
#
# Начало обучения на 20 эпох
# ============================================================
# Epoch 1 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.24it/s, loss=0.8275, acc=81.97%]
# Epoch 1 [Val]: 100%|██████████| 32/32 [00:02<00:00, 12.01it/s, loss=0.7483, acc=86.40%]
# Epoch 1/20:
#   Train - Loss: 0.8275, Acc: 81.97%
#   Val   - Loss: 0.7249, Acc: 86.40%
#   LR: 0.009938
#   ✓ Сохранена лучшая модель (val_acc: 86.40%)
# ------------------------------------------------------------
# Epoch 2 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.38it/s, loss=0.7926, acc=85.22%]
# Epoch 2 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.48it/s, loss=1.2821, acc=84.10%]
# Epoch 2/20:
#   Train - Loss: 0.7926, Acc: 85.22%
#   Val   - Loss: 1.2020, Acc: 84.10%
#   LR: 0.009755
# ------------------------------------------------------------
# Epoch 3 [Train]: 100%|██████████| 125/125 [00:18<00:00,  6.85it/s, loss=0.7959, acc=87.03%]
# Epoch 3 [Val]: 100%|██████████| 32/32 [00:03<00:00,  9.17it/s, loss=0.9728, acc=85.90%]
# Epoch 3/20:
#   Train - Loss: 0.7959, Acc: 87.03%
#   Val   - Loss: 0.9120, Acc: 85.90%
#   LR: 0.009455
# ------------------------------------------------------------
# Epoch 4 [Train]: 100%|██████████| 125/125 [00:18<00:00,  6.92it/s, loss=0.6386, acc=88.95%]
# Epoch 4 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.97it/s, loss=0.7906, acc=87.50%]
# Epoch 4/20:
#   Train - Loss: 0.6386, Acc: 88.95%
#   Val   - Loss: 0.7906, Acc: 87.50%
#   LR: 0.009045
#   ✓ Сохранена лучшая модель (val_acc: 87.50%)
# ------------------------------------------------------------
# Epoch 5 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.36it/s, loss=0.7164, acc=88.40%]
# Epoch 5 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.56it/s, loss=0.7165, acc=88.20%]
# Epoch 5/20:
#   Train - Loss: 0.7164, Acc: 88.40%
#   Val   - Loss: 0.6941, Acc: 88.20%
#   LR: 0.008536
#   ✓ Сохранена лучшая модель (val_acc: 88.20%)
# ------------------------------------------------------------
# Epoch 6 [Train]: 100%|██████████| 125/125 [00:18<00:00,  6.90it/s, loss=0.5866, acc=89.78%]
# Epoch 6 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.95it/s, loss=0.7469, acc=88.10%]
# Epoch 6/20:
#   Train - Loss: 0.5866, Acc: 89.78%
#   Val   - Loss: 0.7469, Acc: 88.10%
#   LR: 0.007939
# ------------------------------------------------------------
# Epoch 7 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.47it/s, loss=0.5243, acc=90.25%]
# Epoch 7 [Val]: 100%|██████████| 32/32 [00:03<00:00, 10.00it/s, loss=0.7183, acc=87.70%]
# Epoch 7/20:
#   Train - Loss: 0.5243, Acc: 90.25%
#   Val   - Loss: 0.6958, Acc: 87.70%
#   LR: 0.007270
# ------------------------------------------------------------
# Epoch 8 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.14it/s, loss=0.4984, acc=90.72%]
# Epoch 8 [Val]: 100%|██████████| 32/32 [00:02<00:00, 12.03it/s, loss=0.7264, acc=88.60%]
# Epoch 8/20:
#   Train - Loss: 0.4984, Acc: 90.72%
#   Val   - Loss: 0.7037, Acc: 88.60%
#   LR: 0.006545
#   ✓ Сохранена лучшая модель (val_acc: 88.60%)
# ------------------------------------------------------------
# Epoch 9 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.31it/s, loss=0.5828, acc=89.33%]
# Epoch 9 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.37it/s, loss=0.6887, acc=89.00%]
# Epoch 9/20:
#   Train - Loss: 0.5828, Acc: 89.33%
#   Val   - Loss: 0.6672, Acc: 89.00%
#   LR: 0.005782
#   ✓ Сохранена лучшая модель (val_acc: 89.00%)
# ------------------------------------------------------------
# Epoch 10 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.47it/s, loss=0.4518, acc=91.03%]
# Epoch 10 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.90it/s, loss=0.6572, acc=88.80%]
# Epoch 10/20:
#   Train - Loss: 0.4518, Acc: 91.03%
#   Val   - Loss: 0.6367, Acc: 88.80%
#   LR: 0.005000
# ------------------------------------------------------------
# Epoch 11 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.36it/s, loss=0.4249, acc=91.12%]
# Epoch 11 [Val]: 100%|██████████| 32/32 [00:03<00:00,  8.64it/s, loss=0.7776, acc=86.70%]
# Epoch 11/20:
#   Train - Loss: 0.4249, Acc: 91.12%
#   Val   - Loss: 0.7776, Acc: 86.70%
#   LR: 0.004218
# ------------------------------------------------------------
# Epoch 12 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.35it/s, loss=0.3921, acc=91.53%]
# Epoch 12 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.84it/s, loss=0.6278, acc=89.00%]
# Epoch 12/20:
#   Train - Loss: 0.3921, Acc: 91.53%
#   Val   - Loss: 0.5886, Acc: 89.00%
#   LR: 0.003455
# ------------------------------------------------------------
# Epoch 13 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.11it/s, loss=0.3541, acc=91.92%]
# Epoch 13 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.20it/s, loss=0.5579, acc=89.90%]
# Epoch 13/20:
#   Train - Loss: 0.3541, Acc: 91.92%
#   Val   - Loss: 0.5579, Acc: 89.90%
#   LR: 0.002730
#   ✓ Сохранена лучшая модель (val_acc: 89.90%)
# ------------------------------------------------------------
# Epoch 14 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.38it/s, loss=0.2856, acc=92.25%]
# Epoch 14 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.87it/s, loss=0.5642, acc=89.60%]
# Epoch 14/20:
#   Train - Loss: 0.2856, Acc: 92.25%
#   Val   - Loss: 0.5465, Acc: 89.60%
#   LR: 0.002061
# ------------------------------------------------------------
# Epoch 15 [Train]: 100%|██████████| 125/125 [00:18<00:00,  6.89it/s, loss=0.3127, acc=92.88%]
# Epoch 15 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.83it/s, loss=0.5767, acc=90.10%]
# Epoch 15/20:
#   Train - Loss: 0.3127, Acc: 92.88%
#   Val   - Loss: 0.5407, Acc: 90.10%
#   LR: 0.001464
#   ✓ Сохранена лучшая модель (val_acc: 90.10%)
# ------------------------------------------------------------
# Epoch 16 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.50it/s, loss=0.2868, acc=93.05%]
# Epoch 16 [Val]: 100%|██████████| 32/32 [00:02<00:00, 12.20it/s, loss=0.5615, acc=90.30%]
# Epoch 16/20:
#   Train - Loss: 0.2868, Acc: 93.05%
#   Val   - Loss: 0.5264, Acc: 90.30%
#   LR: 0.000955
#   ✓ Сохранена лучшая модель (val_acc: 90.30%)
# ------------------------------------------------------------
# Epoch 17 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.00it/s, loss=0.2494, acc=92.92%]
# Epoch 17 [Val]: 100%|██████████| 32/32 [00:02<00:00, 12.02it/s, loss=0.5676, acc=90.00%]
# Epoch 17/20:
#   Train - Loss: 0.2494, Acc: 92.92%
#   Val   - Loss: 0.5321, Acc: 90.00%
#   LR: 0.000545
# ------------------------------------------------------------
# Epoch 18 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.43it/s, loss=0.2462, acc=93.45%]
# Epoch 18 [Val]: 100%|██████████| 32/32 [00:02<00:00, 11.33it/s, loss=0.5250, acc=90.10%]
# Epoch 18/20:
#   Train - Loss: 0.2462, Acc: 93.45%
#   Val   - Loss: 0.5250, Acc: 90.10%
#   LR: 0.000245
# ------------------------------------------------------------
# Epoch 19 [Train]: 100%|██████████| 125/125 [00:17<00:00,  7.23it/s, loss=0.2259, acc=93.90%]
# Epoch 19 [Val]: 100%|██████████| 32/32 [00:02<00:00, 12.19it/s, loss=0.5396, acc=90.10%]
# Epoch 19/20:
#   Train - Loss: 0.2259, Acc: 93.90%
#   Val   - Loss: 0.5227, Acc: 90.10%
#   LR: 0.000062
# ------------------------------------------------------------
# Epoch 20 [Train]: 100%|██████████| 125/125 [00:16<00:00,  7.53it/s, loss=0.2197, acc=93.97%]
# Epoch 20 [Val]: 100%|██████████| 32/32 [00:03<00:00, 10.18it/s, loss=0.5523, acc=90.00%]
# Epoch 20/20:
#   Train - Loss: 0.2197, Acc: 93.97%
#   Val   - Loss: 0.5178, Acc: 90.00%
#   LR: 0.000000
# ------------------------------------------------------------
#
# ============================================================
# Обучение завершено!
# Лучшая val accuracy: 90.30%
# Финальная val accuracy: 90.00%
# Модели сохранены в директории 'checkpoints/'
# Логи TensorBoard: runs/vit_20251229_042332
# ============================================================

# %%
"""
Профилировка моделей с использованием torch.profiler.
Сравнение CNN и ViT-Tiny по использованию ресурсов.
"""

import argparse
import os
import torch
import torch.nn as nn
from torch.profiler import profile, record_function, ProfilerActivity
from tqdm import tqdm


def profile_model(
    model: nn.Module,
    data_loader,
    device: torch.device,
    num_steps: int,
    model_name: str,
    output_dir: str = 'results',
    save_tensorboard=False,
    save_chrome_trace=True
):
    """
    Профилирует модель на заданном количестве шагов.

    Args:
        model: Модель для профилировки
        data_loader: DataLoader с данными
        device: Устройство (CPU/GPU)
        num_steps: Количество шагов для профилировки
        model_name: Название модели для сохранения результатов
        output_dir: Директория для сохранения результатов
    """
    model.eval()
    criterion = nn.CrossEntropyLoss()

    os.makedirs(output_dir, exist_ok=True)
    trace_path = os.path.join(output_dir, f'profiler_trace_{model_name}.json')

    print(f"\nПрофилировка модели: {model_name}")
    print(f"Количество шагов: {num_steps}")
    print(f"Устройство: {device}")
    print("-" * 60)

    # Настройка профайлера
    activities = [ProfilerActivity.CPU]
    if torch.cuda.is_available():
        activities.append(ProfilerActivity.CUDA)

    with profile(
        activities=activities,
        record_shapes=True,
        profile_memory=True,
        with_stack=True,
        # Убираем on_trace_ready, чтобы сохранить вручную
    ) as prof:

        data_iter = iter(data_loader)
        pbar = tqdm(range(num_steps), desc='Профилировка')

        for step in pbar:
            try:
                images, labels = next(data_iter)
            except StopIteration:
                data_iter = iter(data_loader)
                images, labels = next(data_iter)

            images, labels = images.to(device), labels.to(device)

            with record_function("forward"):
                with torch.no_grad():
                    outputs = model(images)
                    loss = criterion(outputs, labels)

            prof.step()

    # Сохранение trace в JSON формате для Chrome Tracing
    prof.export_chrome_trace(trace_path)
    print(f"\nTrace сохранен: {trace_path}")
    print(f"Откройте в Chrome: chrome://tracing")

    # Опционально: сохраняем для TensorBoard отдельно
    tensorboard_dir = f'runs/profiler_{model_name}'
    os.makedirs(tensorboard_dir, exist_ok=True)
    print(f"TensorBoard логи: {tensorboard_dir}")

    # Вывод статистики
    print("\n" + "="*60)
    print("СТАТИСТИКА ПО CPU")
    print("="*60)
    print(prof.key_averages().table(
        sort_by="cpu_time_total",
        row_limit=20
    ))

    if torch.cuda.is_available():
        print("\n" + "="*60)
        print("СТАТИСТИКА ПО CUDA")
        print("="*60)
        print(prof.key_averages().table(
            sort_by="cuda_time_total",
            row_limit=20
        ))

    # Сохранение статистики в файл
    stats_path = os.path.join(output_dir, f'profiler_stats_{model_name}.txt')
    with open(stats_path, 'w') as f:
        f.write("="*60 + "\n")
        f.write(f"ПРОФИЛИРОВКА МОДЕЛИ: {model_name}\n")
        f.write("="*60 + "\n\n")

        f.write("СТАТИСТИКА ПО CPU\n")
        f.write("-"*60 + "\n")
        f.write(prof.key_averages().table(
            sort_by="cpu_time_total",
            row_limit=30
        ))
        f.write("\n\n")

        if torch.cuda.is_available():
            f.write("СТАТИСТИКА ПО CUDA\n")
            f.write("-"*60 + "\n")
            f.write(prof.key_averages().table(
                sort_by="cuda_time_total",
                row_limit=30
            ))

    print(f"\nСтатистика сохранена: {stats_path}")

    return prof


def compare_models(
    cnn_prof,
    vit_prof,
    output_dir: str = 'results'
):
    """
    Сравнивает профили двух моделей.

    Args:
        cnn_prof: Профиль CNN модели
        vit_prof: Профиль ViT модели
        output_dir: Директория для сохранения результатов
    """
    print("\n" + "="*60)
    print("СРАВНЕНИЕ МОДЕЛЕЙ")
    print("="*60)

    # Получаем ключевые метрики
    cnn_stats = cnn_prof.key_averages()
    vit_stats = vit_prof.key_averages()

    # Суммарное время CPU
    cnn_cpu_time = sum([item.cpu_time_total for item in cnn_stats])
    vit_cpu_time = sum([item.cpu_time_total for item in vit_stats])

    print(f"\nВремя CPU:")
    print(f"  CNN:      {cnn_cpu_time / 1e6:.2f} ms")
    print(f"  ViT-Tiny: {vit_cpu_time / 1e6:.2f} ms")
    print(f"  Разница:  {abs(cnn_cpu_time - vit_cpu_time) / 1e6:.2f} ms")
    print(f"  Быстрее:  {'CNN' if cnn_cpu_time < vit_cpu_time else 'ViT-Tiny'}")

    if torch.cuda.is_available():
        # Суммарное время CUDA
        cnn_cuda_time = sum([getattr(item, "cuda_time_total", 0) for item in cnn_stats])
        vit_cuda_time = sum([getattr(item, "cuda_time_total", 0) for item in vit_stats])

        print(f"\nВремя CUDA:")
        print(f"  CNN:      {cnn_cuda_time / 1e6:.2f} ms")
        print(f"  ViT-Tiny: {vit_cuda_time / 1e6:.2f} ms")
        print(f"  Разница:  {abs(cnn_cuda_time - vit_cuda_time) / 1e6:.2f} ms")
        print(f"  Быстрее:  {'CNN' if cnn_cuda_time < vit_cuda_time else 'ViT-Tiny'}")

    # Сохранение сравнения
    comparison_path = os.path.join(output_dir, 'profiler_comparison.txt')
    with open(comparison_path, 'w') as f:
        f.write("="*60 + "\n")
        f.write("СРАВНЕНИЕ МОДЕЛЕЙ: CNN vs ViT-Tiny\n")
        f.write("="*60 + "\n\n")

        f.write(f"Время CPU:\n")
        f.write(f"  CNN:      {cnn_cpu_time / 1e6:.2f} ms\n")
        f.write(f"  ViT-Tiny: {vit_cpu_time / 1e6:.2f} ms\n")
        f.write(f"  Разница:  {abs(cnn_cpu_time - vit_cpu_time) / 1e6:.2f} ms\n")
        f.write(f"  Быстрее:  {'CNN' if cnn_cpu_time < vit_cpu_time else 'ViT-Tiny'}\n\n")

        if torch.cuda.is_available():
            f.write(f"Время CUDA:\n")
            f.write(f"  CNN:      {cnn_cuda_time / 1e6:.2f} ms\n")
            f.write(f"  ViT-Tiny: {vit_cuda_time / 1e6:.2f} ms\n")
            f.write(f"  Разница:  {abs(cnn_cuda_time - vit_cuda_time) / 1e6:.2f} ms\n")
            f.write(f"  Быстрее:  {'CNN' if cnn_cuda_time < vit_cuda_time else 'ViT-Tiny'}\n")

    print(f"\nСравнение сохранено: {comparison_path}")

# %%
OUTPUT_DIR = Path("./traces")
OUTPUT_DIR.mkdir(exist_ok=True)

# %%
model = 'both'
data_dir = DIR_PATH
num_steps = 100
batch_size = 32
seed = 42
output_dir = str(OUTPUT_DIR)


# Установка seed
set_seed(seed)

# Устройство
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Используется устройство: {device}")

# Загрузка данных
train_loader, _, num_classes = get_dataloaders(
    data_dir,
    batch_size=batch_size,
    num_workers=2,
    seed=seed
)

profiles = {}

# Профилировка CNN
if model in ['cnn', 'both']:
    print("\n" + "="*60)
    print("ПРОФИЛИРОВКА CNN")
    print("="*60)

    cnn_model = SimpleCNN(num_classes=num_classes).to(device)
    cnn_prof = profile_model(
        cnn_model, train_loader, device,
        num_steps, 'cnn', output_dir
    )
    profiles['cnn'] = cnn_prof

# Профилировка ViT
if model in ['vit', 'both']:
    print("\n" + "="*60)
    print("ПРОФИЛИРОВКА ViT-Tiny")
    print("="*60)

    vit_model = ViTLinearProbe(num_classes=num_classes, pretrained=True).to(device)
    vit_prof = profile_model(
        vit_model, train_loader, device,
        num_steps, 'vit', output_dir
    )
    profiles['vit'] = vit_prof

# Сравнение моделей
if model == 'both':
    compare_models(profiles['cnn'], profiles['vit'], output_dir)

print("\n" + "="*60)
print("ПРОФИЛИРОВКА ЗАВЕРШЕНА")
print("="*60)
print(f"\nРезультаты сохранены в директории: {output_dir}/")
print("\nДля просмотра trace:")
print("  1. Откройте Chrome и перейдите на chrome://tracing")
print(f"  2. Загрузите файл: {output_dir}/profiler_trace_*.json")
print("\nДля просмотра TensorBoard логов:")
print("  tensorboard --logdir runs")
# Out:
# Используется устройство: cuda
# Загружен датасет:
#   - Классы: ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
#   - Количество классов: 10
#   - Обучающая выборка: 4000 изображений
#   - Валидационная выборка: 1000 изображений
#
# ============================================================
# ПРОФИЛИРОВКА CNN
# ============================================================
#
# Профилировка модели: cnn
# Количество шагов: 100
# Устройство: cuda
# ------------------------------------------------------------
# Профилировка: 100%|██████████| 100/100 [00:17<00:00,  5.57it/s]
# Trace сохранен: traces/profiler_trace_cnn.json
# Откройте в Chrome: chrome://tracing
# TensorBoard логи: runs/profiler_cnn
#
# ============================================================
# СТАТИСТИКА ПО CPU
# ============================================================
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        94.51%       16.516s        94.54%       16.523s     165.226ms       0.000us         0.00%      33.402ms     334.019us           0 B           0 B           0 B           0 B           100
#                                                 forward         1.12%     195.416ms         3.25%     567.981ms       5.680ms       0.000us         0.00%        4.239s      42.393ms           0 B           0 B       2.00 KB    -217.90 GB           100
#                                                aten::to         0.04%       7.513ms         2.21%     385.550ms       1.285ms       0.000us         0.00%     166.105ms     553.682us           0 B           0 B       1.79 GB           0 B           300
#                                          aten::_to_copy         0.04%       7.514ms         2.16%     378.037ms       1.890ms       0.000us         0.00%     166.105ms     830.523us           0 B           0 B       1.79 GB           0 B           200
#                                             aten::copy_         0.04%       6.522ms         2.08%     363.695ms       1.818ms     166.105ms         3.77%     166.105ms     830.523us           0 B           0 B           0 B           0 B           200
#                                   cudaStreamSynchronize         1.98%     346.160ms         1.98%     346.167ms       1.731ms       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B           200
#                                            aten::conv2d         0.05%       8.952ms         0.75%     131.317ms     437.724us       0.000us         0.00%        2.363s       7.877ms           0 B           0 B      66.99 GB           0 B           300
#                                       aten::convolution         0.04%       6.826ms         0.70%     122.365ms     407.884us       0.000us         0.00%        2.363s       7.877ms           0 B           0 B      66.99 GB           0 B           300
#                                      aten::_convolution         0.11%      19.074ms         0.66%     115.539ms     385.131us       0.000us         0.00%        2.363s       7.877ms           0 B           0 B      66.99 GB           0 B           300
#                                        cudaLaunchKernel         0.48%      83.397ms         0.48%      83.397ms      27.799us       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B          3000
#                                        aten::batch_norm         0.04%       6.276ms         0.47%      81.312ms     271.041us       0.000us         0.00%     663.261ms       2.211ms           0 B           0 B      66.99 GB           0 B           300
#                            aten::_batch_norm_impl_index         0.04%       6.532ms         0.43%      75.036ms     250.120us       0.000us         0.00%     663.261ms       2.211ms           0 B           0 B      66.99 GB           0 B           300
#                                 aten::cudnn_convolution         0.26%      45.800ms         0.40%      69.550ms     231.832us        1.760s        39.95%        1.760s       5.867ms           0 B           0 B      66.99 GB      66.99 GB           300
#                                  aten::cudnn_batch_norm         0.21%      36.118ms         0.39%      68.504ms     228.345us     663.261ms        15.06%     663.261ms       2.211ms           0 B           0 B      66.99 GB           0 B           300
#                                            aten::linear         0.01%       2.098ms         0.31%      54.009ms     270.043us       0.000us         0.00%      20.908ms     104.541us           0 B           0 B       6.40 MB           0 B           200
#                                              aten::relu         0.05%       8.423ms         0.24%      41.414ms     103.535us       0.000us         0.00%     604.035ms       1.510ms           0 B           0 B      67.00 GB           0 B           400
#                                             aten::addmm         0.13%      23.178ms         0.23%      40.312ms     201.559us      20.908ms         0.47%      20.908ms     104.541us           0 B           0 B       6.40 MB       6.40 MB           200
#                                        aten::max_pool2d         0.06%       9.616ms         0.19%      33.638ms     112.127us       0.000us         0.00%     553.081ms       1.844ms           0 B           0 B      16.75 GB     -33.50 GB           300
#                                         aten::clamp_min         0.10%      17.856ms         0.19%      32.991ms      82.478us     604.035ms        13.71%     604.035ms       1.510ms           0 B           0 B      67.00 GB      67.00 GB           400
#                           aten::max_pool2d_with_indices         0.08%      13.861ms         0.14%      24.022ms      80.075us     553.081ms        12.55%     553.081ms       1.844ms           0 B           0 B      50.24 GB      50.24 GB           300
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 17.476s
# Self CUDA time total: 4.405s
#
#
# ============================================================
# СТАТИСТИКА ПО CUDA
# ============================================================
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                 forward         0.00%       0.000us         0.00%       0.000us       0.000us        4.245s        96.37%        4.245s      42.454ms           0 B           0 B           0 B           0 B           100
#                                                 forward         1.12%     195.416ms         3.25%     567.981ms       5.680ms       0.000us         0.00%        4.239s      42.393ms           0 B           0 B       2.00 KB    -217.90 GB           100
#                                            aten::conv2d         0.05%       8.952ms         0.75%     131.317ms     437.724us       0.000us         0.00%        2.363s       7.877ms           0 B           0 B      66.99 GB           0 B           300
#                                       aten::convolution         0.04%       6.826ms         0.70%     122.365ms     407.884us       0.000us         0.00%        2.363s       7.877ms           0 B           0 B      66.99 GB           0 B           300
#                                      aten::_convolution         0.11%      19.074ms         0.66%     115.539ms     385.131us       0.000us         0.00%        2.363s       7.877ms           0 B           0 B      66.99 GB           0 B           300
#                                 aten::cudnn_convolution         0.26%      45.800ms         0.40%      69.550ms     231.832us        1.760s        39.95%        1.760s       5.867ms           0 B           0 B      66.99 GB      66.99 GB           300
#                                   volta_sgemm_128x64_nn         0.00%       0.000us         0.00%       0.000us       0.000us     818.023ms        18.57%     818.023ms       4.090ms           0 B           0 B           0 B           0 B           200
#                                        aten::batch_norm         0.04%       6.276ms         0.47%      81.312ms     271.041us       0.000us         0.00%     663.261ms       2.211ms           0 B           0 B      66.99 GB           0 B           300
#                            aten::_batch_norm_impl_index         0.04%       6.532ms         0.43%      75.036ms     250.120us       0.000us         0.00%     663.261ms       2.211ms           0 B           0 B      66.99 GB           0 B           300
#                                  aten::cudnn_batch_norm         0.21%      36.118ms         0.39%      68.504ms     228.345us     663.261ms        15.06%     663.261ms       2.211ms           0 B           0 B      66.99 GB           0 B           300
# void cudnn::bn_fw_inf_1C11_kernel_NCHW<float, float,...         0.00%       0.000us         0.00%       0.000us       0.000us     663.261ms        15.06%     663.261ms       2.211ms           0 B           0 B           0 B           0 B           300
#                                              aten::relu         0.05%       8.423ms         0.24%      41.414ms     103.535us       0.000us         0.00%     604.035ms       1.510ms           0 B           0 B      67.00 GB           0 B           400
#                                         aten::clamp_min         0.10%      17.856ms         0.19%      32.991ms      82.478us     604.035ms        13.71%     604.035ms       1.510ms           0 B           0 B      67.00 GB      67.00 GB           400
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us     604.035ms        13.71%     604.035ms       1.510ms           0 B           0 B           0 B           0 B           400
#                                              aten::add_         0.08%      14.052ms         0.10%      18.320ms      61.067us     603.164ms        13.69%     603.164ms       2.011ms           0 B           0 B           0 B           0 B           300
# void at::native::elementwise_kernel<128, 2, at::nati...         0.00%       0.000us         0.00%       0.000us       0.000us     603.164ms        13.69%     603.164ms       2.011ms           0 B           0 B           0 B           0 B           300
#                                        aten::max_pool2d         0.06%       9.616ms         0.19%      33.638ms     112.127us       0.000us         0.00%     553.081ms       1.844ms           0 B           0 B      16.75 GB     -33.50 GB           300
#                           aten::max_pool2d_with_indices         0.08%      13.861ms         0.14%      24.022ms      80.075us     553.081ms        12.55%     553.081ms       1.844ms           0 B           0 B      50.24 GB      50.24 GB           300
# void at::native::(anonymous namespace)::max_pool_for...         0.00%       0.000us         0.00%       0.000us       0.000us     553.081ms        12.55%     553.081ms       1.844ms           0 B           0 B           0 B           0 B           300
# void cudnn::winograd_nonfused::winogradForwardOutput...         0.00%       0.000us         0.00%       0.000us       0.000us     424.949ms         9.65%     424.949ms       2.125ms           0 B           0 B           0 B           0 B           200
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 17.476s
# Self CUDA time total: 4.405s
#
#
# Статистика сохранена: traces/profiler_stats_cnn.txt
#
# ============================================================
# ПРОФИЛИРОВКА ViT-Tiny
# ============================================================
# ViT-Tiny модель загружена:
#   - Модель: vit_tiny_patch16_224
#   - Предобучена: True
#   - Размерность признаков: 192
#   - Количество классов: 10
#   - Backbone заморожен: все параметры requires_grad=False
#
# Профилировка модели: vit
# Количество шагов: 100
# Устройство: cuda
# ------------------------------------------------------------
# Профилировка: 100%|██████████| 100/100 [00:18<00:00,  5.52it/s]
# Trace сохранен: traces/profiler_trace_vit.json
# Откройте в Chrome: chrome://tracing
# TensorBoard логи: runs/profiler_vit
#
# ============================================================
# СТАТИСТИКА ПО CPU
# ============================================================
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# enumerate(DataLoader)#_MultiProcessingDataLoaderIter...        75.70%       13.459s        75.75%       13.467s     134.671ms       0.000us         0.00%       1.990ms      19.898us           0 B           0 B           0 B           0 B           100
#                                                 forward         8.67%        1.542s        21.81%        3.877s      38.773ms       0.000us         0.00%        4.145s      41.446ms           0 B          16 B       2.00 KB    -101.11 GB           100
#                                            aten::linear         0.86%     153.081ms         5.89%        1.047s     213.582us       0.000us         0.00%        2.382s     486.084us           0 B           0 B      48.70 GB           0 B          4900
#                                             aten::addmm         2.84%     505.310ms         3.67%     652.499ms     133.163us        2.380s        55.25%        2.382s     486.084us           0 B           0 B      48.70 GB      48.70 GB          4900
#                                                aten::to         0.02%       3.321ms         2.38%     423.535ms       1.412ms       0.000us         0.00%     167.229ms     557.430us           0 B           0 B       1.79 GB           0 B           300
#                                          aten::_to_copy         0.04%       7.558ms         2.36%     420.213ms       2.101ms       0.000us         0.00%     167.229ms     836.146us           0 B           0 B       1.79 GB           0 B           200
#                                        aten::layer_norm         0.24%      42.643ms         2.34%     416.881ms     166.753us       0.000us         0.00%     308.580ms     123.432us           0 B           0 B      11.94 GB    -121.70 MB          2500
#                                             aten::copy_         0.04%       6.532ms         2.28%     406.128ms       2.031ms     167.229ms         3.88%     167.229ms     836.146us           0 B           0 B           0 B           0 B           200
#                                   cudaStreamSynchronize         2.20%     391.904ms         2.20%     391.904ms       1.960ms       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B           200
#                                 aten::native_layer_norm         0.92%     162.823ms         2.10%     374.238ms     149.695us     308.580ms         7.16%     308.580ms     123.432us           0 B           0 B      12.06 GB           0 B          2500
#                                        cudaLaunchKernel         2.02%     359.050ms         2.02%     359.050ms      27.833us       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B         12900
#                      aten::scaled_dot_product_attention         0.22%      39.403ms         1.85%     328.553ms     273.794us       0.000us         0.00%     996.649ms     830.541us           0 B     -18.75 KB       5.98 GB           0 B          1200
#           aten::_scaled_dot_product_efficient_attention         0.30%      52.540ms         1.63%     289.151ms     240.959us       0.000us         0.00%     996.649ms     830.541us      18.75 KB           0 B       5.98 GB           0 B          1200
#                                               aten::add         0.69%     121.865ms         1.10%     196.182ms      78.473us     150.144ms         3.49%     150.144ms      60.058us           0 B           0 B      11.84 GB      11.84 GB          2500
#                                             aten::empty         1.08%     191.390ms         1.08%     191.396ms      15.557us       0.000us         0.00%       0.000us       0.000us      50.02 KB      50.02 KB      18.04 GB      18.04 GB         12303
#                      aten::_efficient_attention_forward         0.38%      67.299ms         0.99%     175.250ms     146.041us     995.594ms        23.11%     996.649ms     830.541us      18.75 KB           0 B       5.98 GB           0 B          1200
#                                         aten::transpose         0.57%     101.393ms         0.87%     154.703ms      14.064us       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B         11000
#                                                 aten::t         0.32%      57.161ms         0.74%     130.823ms      26.699us       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B          4900
#                                              aten::view         0.69%     121.853ms         0.69%     121.853ms       7.084us       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B         17200
#                                           aten::reshape         0.29%      51.968ms         0.62%     109.365ms      14.982us       0.000us         0.00%       0.000us       0.000us           0 B           0 B           0 B           0 B          7300
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 17.779s
# Self CUDA time total: 4.308s
#
#
# ============================================================
# СТАТИСТИКА ПО CUDA
# ============================================================
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg       CPU Mem  Self CPU Mem      CUDA Mem  Self CUDA Mem    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                 forward         0.00%       0.000us         0.00%       0.000us       0.000us        4.603s       106.85%        4.603s      46.029ms           0 B           0 B           0 B           0 B           100
#                                                 forward         8.67%        1.542s        21.81%        3.877s      38.773ms       0.000us         0.00%        4.145s      41.446ms           0 B          16 B       2.00 KB    -101.11 GB           100
#                                            aten::linear         0.86%     153.081ms         5.89%        1.047s     213.582us       0.000us         0.00%        2.382s     486.084us           0 B           0 B      48.70 GB           0 B          4900
#                                             aten::addmm         2.84%     505.310ms         3.67%     652.499ms     133.163us        2.380s        55.25%        2.382s     486.084us           0 B           0 B      48.70 GB      48.70 GB          4900
#                                    volta_sgemm_64x64_tn         0.00%       0.000us         0.00%       0.000us       0.000us        1.655s        38.41%        1.655s     459.613us           0 B           0 B           0 B           0 B          3600
#                      aten::scaled_dot_product_attention         0.22%      39.403ms         1.85%     328.553ms     273.794us       0.000us         0.00%     996.649ms     830.541us           0 B     -18.75 KB       5.98 GB           0 B          1200
#           aten::_scaled_dot_product_efficient_attention         0.30%      52.540ms         1.63%     289.151ms     240.959us       0.000us         0.00%     996.649ms     830.541us      18.75 KB           0 B       5.98 GB           0 B          1200
#                      aten::_efficient_attention_forward         0.38%      67.299ms         0.99%     175.250ms     146.041us     995.594ms        23.11%     996.649ms     830.541us      18.75 KB           0 B       5.98 GB           0 B          1200
# fmha_cutlassF_f32_aligned_64x64_rf_sm75(PyTorchMemEf...         0.00%       0.000us         0.00%       0.000us       0.000us     995.594ms        23.11%     995.594ms     829.661us           0 B           0 B           0 B           0 B          1200
#                                   volta_sgemm_128x64_tn         0.00%       0.000us         0.00%       0.000us       0.000us     723.851ms        16.80%     723.851ms     603.209us           0 B           0 B           0 B           0 B          1200
#                                        aten::layer_norm         0.24%      42.643ms         2.34%     416.881ms     166.753us       0.000us         0.00%     308.580ms     123.432us           0 B           0 B      11.94 GB    -121.70 MB          2500
#                                 aten::native_layer_norm         0.92%     162.823ms         2.10%     374.238ms     149.695us     308.580ms         7.16%     308.580ms     123.432us           0 B           0 B      12.06 GB           0 B          2500
# void at::native::(anonymous namespace)::vectorized_l...         0.00%       0.000us         0.00%       0.000us       0.000us     308.580ms         7.16%     308.580ms     123.432us           0 B           0 B           0 B           0 B          2500
#                                              aten::gelu         0.34%      60.062ms         0.48%      84.454ms      70.379us     195.843ms         4.55%     195.843ms     163.203us           0 B           0 B      21.64 GB      21.64 GB          1200
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us     195.843ms         4.55%     195.843ms     163.203us           0 B           0 B           0 B           0 B          1200
#                                                aten::to         0.02%       3.321ms         2.38%     423.535ms       1.412ms       0.000us         0.00%     167.229ms     557.430us           0 B           0 B       1.79 GB           0 B           300
#                                          aten::_to_copy         0.04%       7.558ms         2.36%     420.213ms       2.101ms       0.000us         0.00%     167.229ms     836.146us           0 B           0 B       1.79 GB           0 B           200
#                                             aten::copy_         0.04%       6.532ms         2.28%     406.128ms       2.031ms     167.229ms         3.88%     167.229ms     836.146us           0 B           0 B           0 B           0 B           200
#                          Memcpy HtoD (Pinned -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us     167.229ms         3.88%     167.229ms     836.146us           0 B           0 B           0 B           0 B           200
#                                               aten::add         0.69%     121.865ms         1.10%     196.182ms      78.473us     150.144ms         3.49%     150.144ms      60.058us           0 B           0 B      11.84 GB      11.84 GB          2500
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 17.779s
# Self CUDA time total: 4.308s
#
#
# Статистика сохранена: traces/profiler_stats_vit.txt
#
# ============================================================
# СРАВНЕНИЕ МОДЕЛЕЙ
# ============================================================
#
# Время CPU:
#   CNN:      19.72 ms
#   ViT-Tiny: 24.15 ms
#   Разница:  4.43 ms
#   Быстрее:  CNN
#
# Время CUDA:
#   CNN:      0.00 ms
#   ViT-Tiny: 0.00 ms
#   Разница:  0.00 ms
#   Быстрее:  ViT-Tiny
#
# Сравнение сохранено: traces/profiler_comparison.txt
#
# ============================================================
# ПРОФИЛИРОВКА ЗАВЕРШЕНА
# ============================================================
#
# Результаты сохранены в директории: traces/
#
# Для просмотра trace:
#   1. Откройте Chrome и перейдите на chrome://tracing
#   2. Загрузите файл: traces/profiler_trace_*.json
#
# Для просмотра TensorBoard логов:
#   tensorboard --logdir runs

# %%
"""
Оценка и сравнение моделей CNN и ViT-Tiny.
Вычисление метрик (accuracy, F1), построение confusion matrix.
"""

import os
import csv

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tqdm import tqdm


def load_model(
    model_path: str,
    model_type: str,
    num_classes: int,
    device: torch.device
) -> nn.Module:
    """
    Загружает модель из чекпоинта.

    Args:
        model_path: Путь к чекпоинту
        model_type: Тип модели ('cnn' или 'vit')
        num_classes: Количество классов
        device: Устройство

    Returns:
        Загруженная модель
    """
    # Создаем модель
    if model_type == 'cnn':
        model = SimpleCNN(num_classes=num_classes)
    elif model_type == 'vit':
        model = ViTLinearProbe(num_classes=num_classes, pretrained=False)
    else:
        raise ValueError(f"Неизвестный тип модели: {model_type}")

    # Загружаем веса
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    model = model.to(device)
    model.eval()

    print(f"Модель {model_type} загружена из {model_path}")
    if 'val_acc' in checkpoint:
        print(f"  Сохраненная val accuracy: {checkpoint['val_acc']:.2f}%")

    return model


def evaluate_model(
    model: nn.Module,
    data_loader,
    device: torch.device,
    class_names: list
) -> dict:
    """
    Оценивает модель на данных.

    Args:
        model: Модель для оценки
        data_loader: DataLoader с данными
        device: Устройство
        class_names: Список названий классов

    Returns:
        Словарь с метриками и предсказаниями
    """
    model.eval()

    all_preds = []
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for images, labels in tqdm(data_loader, desc='Оценка'):
            images = images.to(device)
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)
            _, preds = outputs.max(1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())
            all_probs.extend(probs.cpu().numpy())

    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    all_probs = np.array(all_probs)

    # Вычисляем метрики
    accuracy = 100. * (all_preds == all_labels).sum() / len(all_labels)
    macro_f1 = f1_score(all_labels, all_preds, average='macro')

    # Classification report
    report = classification_report(
        all_labels, all_preds,
        target_names=class_names,
        digits=4
    )

    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)

    return {
        'accuracy': accuracy,
        'macro_f1': macro_f1,
        'predictions': all_preds,
        'labels': all_labels,
        'probabilities': all_probs,
        'confusion_matrix': cm,
        'classification_report': report
    }


def plot_confusion_matrix(
    cm: np.ndarray,
    class_names: list,
    model_name: str,
    output_path: str,
    normalize: bool = True
):
    """
    Строит и сохраняет confusion matrix.

    Args:
        cm: Confusion matrix
        class_names: Список названий классов
        model_name: Название модели
        output_path: Путь для сохранения
        normalize: Нормализовать ли матрицу
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        fmt = '.2f'
        title = f'Normalized Confusion Matrix - {model_name}'
    else:
        fmt = 'd'
        title = f'Confusion Matrix - {model_name}'

    plt.figure(figsize=(10, 8))
    sns.heatmap(
        cm,
        annot=True,
        fmt=fmt,
        cmap='Blues',
        xticklabels=class_names,
        yticklabels=class_names,
        cbar_kws={'label': 'Proportion' if normalize else 'Count'}
    )
    plt.title(title, fontsize=14, fontweight='bold')
    plt.ylabel('True Label', fontsize=12)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.tight_layout()
    plt.savefig(output_path, dpi=300, bbox_inches='tight')
    plt.close()

    print(f"Confusion matrix сохранена: {output_path}")


def save_metrics_to_csv(
    metrics_dict: dict,
    output_path: str
):
    """
    Сохраняет метрики в CSV файл.

    Args:
        metrics_dict: Словарь с метриками для разных моделей
        output_path: Путь для сохранения CSV
    """
    with open(output_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['Model', 'Accuracy (%)', 'Macro F1', 'Parameters'])

        for model_name, metrics in metrics_dict.items():
            writer.writerow([
                model_name,
                f"{metrics['accuracy']:.2f}",
                f"{metrics['macro_f1']:.4f}",
                metrics.get('num_params', 'N/A')
            ])

    print(f"Метрики сохранены: {output_path}")


def compare_models(
    cnn_results: dict,
    vit_results: dict,
    output_dir: str
):
    """
    Сравнивает результаты двух моделей.

    Args:
        cnn_results: Результаты CNN
        vit_results: Результаты ViT
        output_dir: Директория для сохранения
    """
    print("\n" + "="*60)
    print("СРАВНЕНИЕ МОДЕЛЕЙ")
    print("="*60)

    print(f"\nCNN:")
    print(f"  Accuracy: {cnn_results['accuracy']:.2f}%")
    print(f"  Macro F1: {cnn_results['macro_f1']:.4f}")

    print(f"\nViT-Tiny:")
    print(f"  Accuracy: {vit_results['accuracy']:.2f}%")
    print(f"  Macro F1: {vit_results['macro_f1']:.4f}")

    print(f"\nРазница:")
    acc_diff = vit_results['accuracy'] - cnn_results['accuracy']
    f1_diff = vit_results['macro_f1'] - cnn_results['macro_f1']
    print(f"  Accuracy: {acc_diff:+.2f}% ({'ViT лучше' if acc_diff > 0 else 'CNN лучше'})")
    print(f"  Macro F1: {f1_diff:+.4f} ({'ViT лучше' if f1_diff > 0 else 'CNN лучше'})")

    # Сохранение сравнения
    comparison_path = os.path.join(output_dir, 'model_comparison.txt')
    with open(comparison_path, 'w') as f:
        f.write("="*60 + "\n")
        f.write("СРАВНЕНИЕ МОДЕЛЕЙ: CNN vs ViT-Tiny\n")
        f.write("="*60 + "\n\n")

        f.write("CNN:\n")
        f.write(f"  Accuracy: {cnn_results['accuracy']:.2f}%\n")
        f.write(f"  Macro F1: {cnn_results['macro_f1']:.4f}\n\n")

        f.write("ViT-Tiny:\n")
        f.write(f"  Accuracy: {vit_results['accuracy']:.2f}%\n")
        f.write(f"  Macro F1: {vit_results['macro_f1']:.4f}\n\n")

        f.write("Разница:\n")
        f.write(f"  Accuracy: {acc_diff:+.2f}% ({'ViT лучше' if acc_diff > 0 else 'CNN лучше'})\n")
        f.write(f"  Macro F1: {f1_diff:+.4f} ({'ViT лучше' if f1_diff > 0 else 'CNN лучше'})\n\n")

        f.write("="*60 + "\n")
        f.write("CLASSIFICATION REPORT - CNN\n")
        f.write("="*60 + "\n")
        f.write(cnn_results['classification_report'])
        f.write("\n\n")

        f.write("="*60 + "\n")
        f.write("CLASSIFICATION REPORT - ViT-Tiny\n")
        f.write("="*60 + "\n")
        f.write(vit_results['classification_report'])

    print(f"\nСравнение сохранено: {comparison_path}")

# %%
model_cnn = './checkpoints/cnn_best.pth'
model_vit = './checkpoints/vit_best.pth'
data_dir = DIR_PATH
batch_size = 32
seed = 42
output_dir = OUTPUT_DIR

# Установка seed
set_seed(seed)

# Устройство
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Используется устройство: {device}")

# Создание директории для результатов
os.makedirs(output_dir, exist_ok=True)

# Загрузка данных
_, val_loader, num_classes = get_dataloaders(
    data_dir,
    batch_size=batch_size,
    num_workers=2,
    seed=seed
)

# Получаем названия классов
from torchvision import datasets
val_dataset = datasets.ImageFolder(root=f"{data_dir}/val")
class_names = val_dataset.classes

print(f"\nКлассы: {class_names}")
print(f"Количество классов: {num_classes}")
print(f"Размер валидационной выборки: {len(val_dataset)}")

# Оценка CNN
print("\n" + "="*60)
print("ОЦЕНКА CNN")
print("="*60)

cnn_model = load_model(model_cnn, 'cnn', num_classes, device)
cnn_results = evaluate_model(cnn_model, val_loader, device, class_names)

print(f"\nРезультаты CNN:")
print(f"  Accuracy: {cnn_results['accuracy']:.2f}%")
print(f"  Macro F1: {cnn_results['macro_f1']:.4f}")

# Сохранение confusion matrix для CNN
plot_confusion_matrix(
    cnn_results['confusion_matrix'],
    class_names,
    'CNN',
    os.path.join(output_dir, 'confusion_matrix_cnn.png')
)

# Оценка ViT
print("\n" + "="*60)
print("ОЦЕНКА ViT-Tiny")
print("="*60)

vit_model = load_model(model_vit, 'vit', num_classes, device)
vit_results = evaluate_model(vit_model, val_loader, device, class_names)

print(f"\nРезультаты ViT-Tiny:")
print(f"  Accuracy: {vit_results['accuracy']:.2f}%")
print(f"  Macro F1: {vit_results['macro_f1']:.4f}")

# Сохранение confusion matrix для ViT
plot_confusion_matrix(
    vit_results['confusion_matrix'],
    class_names,
    'ViT-Tiny',
    os.path.join(output_dir, 'confusion_matrix_vit.png')
)

# Сравнение моделей
compare_models(cnn_results, vit_results, output_dir)

# Сохранение метрик в CSV
metrics_dict = {
    'CNN': {
        'accuracy': cnn_results['accuracy'],
        'macro_f1': cnn_results['macro_f1'],
        'num_params': cnn_model.get_num_parameters() if hasattr(cnn_model, 'get_num_parameters') else 'N/A'
    },
    'ViT-Tiny': {
        'accuracy': vit_results['accuracy'],
        'macro_f1': vit_results['macro_f1'],
        'num_params': vit_model.get_num_parameters() if hasattr(vit_model, 'get_num_parameters') else 'N/A'
    }
}

save_metrics_to_csv(
    metrics_dict,
    os.path.join(output_dir, 'metrics.csv')
)

print("\n" + "="*60)
print("ОЦЕНКА ЗАВЕРШЕНА")
print("="*60)
print(f"\nВсе результаты сохранены в директории: {output_dir}/")
# Out:
# Используется устройство: cuda
# Загружен датасет:
#   - Классы: ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
#   - Количество классов: 10
#   - Обучающая выборка: 4000 изображений
#   - Валидационная выборка: 1000 изображений
#
# Классы: ['airplane', 'bird', 'car', 'cat', 'deer', 'dog', 'horse', 'monkey', 'ship', 'truck']
# Количество классов: 10
# Размер валидационной выборки: 1000
#
# ============================================================
# ОЦЕНКА CNN
# ============================================================
# Модель cnn загружена из ./checkpoints/cnn_best.pth
#   Сохраненная val accuracy: 61.80%
# Оценка: 100%|██████████| 32/32 [00:02<00:00, 11.37it/s]
# Результаты CNN:
#   Accuracy: 61.80%
#   Macro F1: 0.6144
# Confusion matrix сохранена: traces/confusion_matrix_cnn.png
#
# ============================================================
# ОЦЕНКА ViT-Tiny
# ============================================================
# ViT-Tiny модель загружена:
#   - Модель: vit_tiny_patch16_224
#   - Предобучена: False
#   - Размерность признаков: 192
#   - Количество классов: 10
#   - Backbone заморожен: все параметры requires_grad=False
# Модель vit загружена из ./checkpoints/vit_best.pth
#   Сохраненная val accuracy: 90.30%
# Оценка: 100%|██████████| 32/32 [00:02<00:00, 12.25it/s]
# Результаты ViT-Tiny:
#   Accuracy: 90.30%
#   Macro F1: 0.9034
# Confusion matrix сохранена: traces/confusion_matrix_vit.png
#
# ============================================================
# СРАВНЕНИЕ МОДЕЛЕЙ
# ============================================================
#
# CNN:
#   Accuracy: 61.80%
#   Macro F1: 0.6144
#
# ViT-Tiny:
#   Accuracy: 90.30%
#   Macro F1: 0.9034
#
# Разница:
#   Accuracy: +28.50% (ViT лучше)
#   Macro F1: +0.2891 (ViT лучше)
#
# Сравнение сохранено: traces/model_comparison.txt
# Метрики сохранены: traces/metrics.csv
#
# ============================================================
# ОЦЕНКА ЗАВЕРШЕНА
# ============================================================
#
# Все результаты сохранены в директории: traces/

# %%
# !zip -r checkpoints.zip ./checkpoints
# Out:
#   adding: checkpoints/ (stored 0%)
#   adding: checkpoints/cnn_best.pth (deflated 8%)
#   adding: checkpoints/cnn_final.pth (deflated 8%)
#   adding: checkpoints/vit_final.pth (deflated 7%)
#   adding: checkpoints/vit_best.pth (deflated 7%)

# %%
# !zip -r data.zip ./data
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# updating: data/train/cat/000347.png (deflated 0%)
# updating: data/train/cat/000896.png (deflated 0%)
# updating: data/train/cat/002615.png (stored 0%)
# updating: data/train/cat/001063.png (deflated 0%)
# updating: data/train/cat/003188.png (stored 0%)
# updating: data/train/cat/000961.png (stored 0%)
# updating: data/train/cat/001510.png (stored 0%)
# updating: data/train/cat/004349.png (stored 0%)
# updating: data/train/cat/002726.png (stored 0%)
# updating: data/train/cat/004631.png (deflated 0%)
# updating: data/train/cat/004101.png (deflated 1%)
# updating: data/train/cat/003688.png (stored 0%)
# updating: data/train/cat/001919.png (deflated 0%)
# updating: data/train/cat/003721.png (deflated 0%)
# updating: data/train/cat/002273.png (stored 0%)
# updating: data/train/cat/003599.png (deflated 0%)
# updating: data/train/cat/001624.png (deflated 2%)
# updating: data/train/cat/003906.png (stored 0%)
# updating: data/train/cat/001059.png (deflated 0%)
# updating: data/train/cat/002205.png (stored 0%)
# updating: data/train/cat/003321.png (stored 0%)
# updating: data/train/cat/004967.png (deflated 0%)
# updating: data/train/cat/003463.png (deflated 0%)
# updating: data/train/cat/000192.png (stored 0%)
# updating: data/train/cat/003656.png (deflated 0%)
# updating: data/train/cat/003472.png (stored 0%)
# updating: data/train/cat/000859.png (deflated 0%)
# updating: data/train/cat/002182.png (stored 0%)
# updating: data/train/cat/002229.png (deflated 1%)
# updating: data/train/cat/004783.png (stored 0%)
# updating: data/train/cat/004354.png (stored 0%)
# updating: data/train/cat/003312.png (stored 0%)
# updating: data/train/cat/000794.png (stored 0%)
# updating: data/train/cat/002095.png (stored 0%)
# updating: data/train/cat/001617.png (deflated 0%)
# updating: data/train/cat/003566.png (deflated 1%)
# updating: data/train/cat/002533.png (deflated 0%)
# updating: data/train/cat/003455.png (stored 0%)
# updating: data/train/cat/001633.png (stored 0%)
# updating: data/train/cat/004843.png (stored 0%)
# updating: data/train/cat/004776.png (stored 0%)
# updating: data/train/cat/004670.png (stored 0%)
# updating: data/train/cat/001957.png (stored 0%)
# updating: data/train/cat/001446.png (deflated 0%)
# updating: data/train/cat/004047.png (deflated 0%)
# updating: data/train/cat/004495.png (stored 0%)
# updating: data/train/cat/000242.png (stored 0%)
# updating: data/train/cat/002310.png (stored 0%)
# updating: data/train/cat/000529.png (stored 0%)
# updating: data/train/cat/000127.png (stored 0%)
# updating: data/train/cat/001287.png (stored 0%)
# updating: data/train/cat/001619.png (deflated 0%)
# updating: data/train/cat/002103.png (stored 0%)
# updating: data/train/cat/003694.png (stored 0%)
# updating: data/train/cat/004829.png (deflated 0%)
# updating: data/train/cat/000039.png (stored 0%)
# updating: data/train/cat/001800.png (deflated 0%)
# updating: data/train/cat/003983.png (stored 0%)
# updating: data/train/cat/004239.png (stored 0%)
# updating: data/train/cat/001163.png (stored 0%)
# updating: data/train/cat/001355.png (stored 0%)
# updating: data/train/cat/004093.png (deflated 0%)
# updating: data/train/cat/002322.png (deflated 0%)
# updating: data/train/cat/002213.png (stored 0%)
# updating: data/train/cat/002862.png (stored 0%)
# updating: data/train/cat/003626.png (stored 0%)
# updating: data/train/cat/004657.png (deflated 0%)
# updating: data/train/cat/001741.png (stored 0%)
# updating: data/train/cat/004285.png (deflated 0%)
# updating: data/train/cat/001637.png (deflated 1%)
# updating: data/train/cat/000954.png (stored 0%)
# updating: data/train/cat/002153.png (stored 0%)
# updating: data/train/cat/001461.png (stored 0%)
# updating: data/train/cat/002886.png (stored 0%)
# updating: data/train/cat/001100.png (stored 0%)
# updating: data/train/cat/004623.png (stored 0%)
# updating: data/train/cat/004344.png (stored 0%)
# updating: data/train/cat/000679.png (stored 0%)
# updating: data/train/cat/000194.png (deflated 0%)
# updating: data/train/cat/003726.png (stored 0%)
# updating: data/train/cat/003650.png (stored 0%)
# updating: data/train/cat/001974.png (stored 0%)
# updating: data/train/cat/004891.png (deflated 0%)
# updating: data/train/cat/004462.png (deflated 0%)
# updating: data/train/cat/001357.png (stored 0%)
# updating: data/train/cat/000588.png (stored 0%)
# updating: data/train/cat/000802.png (stored 0%)
# updating: data/train/cat/001988.png (stored 0%)
# updating: data/train/cat/000505.png (deflated 0%)
# updating: data/train/cat/001050.png (deflated 0%)
# updating: data/train/cat/003095.png (stored 0%)
# updating: data/train/cat/003982.png (stored 0%)
# updating: data/train/cat/000231.png (stored 0%)
# updating: data/train/cat/004119.png (deflated 1%)
# updating: data/train/cat/002653.png (deflated 0%)
# updating: data/train/cat/003412.png (stored 0%)
# updating: data/train/cat/003526.png (stored 0%)
# updating: data/train/cat/003220.png (stored 0%)
# updating: data/train/cat/004275.png (stored 0%)
# updating: data/train/cat/001685.png (deflated 0%)
# updating: data/train/cat/004077.png (stored 0%)
# updating: data/train/cat/004363.png (stored 0%)
# updating: data/train/cat/003999.png (deflated 0%)
# updating: data/train/cat/002261.png (deflated 0%)
# updating: data/train/cat/003678.png (stored 0%)
# updating: data/train/cat/004685.png (stored 0%)
# updating: data/train/cat/001882.png (stored 0%)
# updating: data/train/cat/001199.png (stored 0%)
# updating: data/train/cat/001941.png (stored 0%)
# updating: data/train/cat/001238.png (deflated 0%)
# updating: data/train/cat/004327.png (deflated 0%)
# updating: data/train/cat/000804.png (deflated 0%)
# updating: data/train/cat/001975.png (deflated 0%)
# updating: data/train/cat/002042.png (stored 0%)
# updating: data/train/cat/004168.png (stored 0%)
# updating: data/train/cat/003890.png (deflated 0%)
# updating: data/train/cat/004200.png (deflated 0%)
# updating: data/train/cat/003961.png (stored 0%)
# updating: data/train/cat/002721.png (deflated 1%)
# updating: data/train/cat/000970.png (stored 0%)
# updating: data/train/cat/001173.png (stored 0%)
# updating: data/train/cat/000810.png (stored 0%)
# updating: data/train/cat/000739.png (deflated 1%)
# updating: data/train/cat/003867.png (stored 0%)
# updating: data/train/cat/000510.png (deflated 0%)
# updating: data/train/cat/004097.png (deflated 1%)
# updating: data/train/cat/000976.png (deflated 0%)
# updating: data/train/cat/002928.png (deflated 0%)
# updating: data/train/cat/002994.png (stored 0%)
# updating: data/train/cat/001579.png (stored 0%)
# updating: data/train/cat/003182.png (stored 0%)
# updating: data/train/cat/000280.png (stored 0%)
# updating: data/train/cat/004071.png (deflated 0%)
# updating: data/train/cat/002998.png (deflated 0%)
# updating: data/train/cat/004842.png (deflated 0%)
# updating: data/train/cat/003416.png (deflated 0%)
# updating: data/train/cat/002250.png (stored 0%)
# updating: data/train/cat/004099.png (stored 0%)
# updating: data/train/cat/001020.png (stored 0%)
# updating: data/train/cat/003105.png (stored 0%)
# updating: data/train/cat/001725.png (stored 0%)
# updating: data/train/cat/003537.png (stored 0%)
# updating: data/train/cat/001925.png (deflated 0%)
# updating: data/train/cat/000326.png (stored 0%)
# updating: data/train/cat/003148.png (stored 0%)
# updating: data/train/cat/000191.png (stored 0%)
# updating: data/train/cat/002342.png (deflated 0%)
# updating: data/train/cat/000777.png (deflated 0%)
# updating: data/train/cat/004922.png (stored 0%)
# updating: data/train/cat/000887.png (stored 0%)
# updating: data/train/cat/004075.png (stored 0%)
# updating: data/train/cat/002600.png (deflated 0%)
# updating: data/train/cat/004125.png (stored 0%)
# updating: data/train/cat/001200.png (stored 0%)
# updating: data/train/cat/003468.png (deflated 0%)
# updating: data/train/cat/002009.png (deflated 0%)
# updating: data/train/cat/003222.png (deflated 0%)
# updating: data/train/cat/004541.png (stored 0%)
# updating: data/train/cat/002360.png (stored 0%)
# updating: data/train/cat/000833.png (deflated 0%)
# updating: data/train/cat/002454.png (deflated 0%)
# updating: data/train/cat/004089.png (stored 0%)
# updating: data/train/cat/000783.png (stored 0%)
# updating: data/train/cat/002010.png (stored 0%)
# updating: data/train/cat/003922.png (stored 0%)
# updating: data/train/cat/002848.png (deflated 0%)
# updating: data/train/cat/004198.png (stored 0%)
# updating: data/train/cat/002435.png (deflated 1%)
# updating: data/train/cat/002399.png (stored 0%)
# updating: data/train/cat/001744.png (deflated 0%)
# updating: data/train/cat/002472.png (deflated 0%)
# updating: data/train/cat/000527.png (deflated 0%)
# updating: data/train/cat/004416.png (deflated 2%)
# updating: data/train/cat/002424.png (deflated 0%)
# updating: data/train/cat/003229.png (stored 0%)
# updating: data/train/cat/001329.png (deflated 0%)
# updating: data/train/cat/003315.png (stored 0%)
# updating: data/train/cat/004738.png (stored 0%)
# updating: data/train/cat/003897.png (deflated 0%)
# updating: data/train/cat/004021.png (stored 0%)
# updating: data/train/cat/000850.png (stored 0%)
# updating: data/train/cat/003146.png (deflated 1%)
# updating: data/train/cat/003277.png (stored 0%)
# updating: data/train/cat/000670.png (deflated 0%)
# updating: data/train/cat/003211.png (stored 0%)
# updating: data/train/cat/003459.png (stored 0%)
# updating: data/train/cat/003514.png (stored 0%)
# updating: data/train/cat/004532.png (deflated 0%)
# updating: data/train/cat/002018.png (stored 0%)
# updating: data/train/cat/003771.png (stored 0%)
# updating: data/train/cat/003451.png (stored 0%)
# updating: data/train/cat/001709.png (deflated 1%)
# updating: data/train/cat/000327.png (stored 0%)
# updating: data/train/cat/003465.png (stored 0%)
# updating: data/train/cat/002681.png (deflated 0%)
# updating: data/train/cat/001654.png (stored 0%)
# updating: data/train/cat/003336.png (deflated 0%)
# updating: data/train/cat/001707.png (stored 0%)
# updating: data/train/cat/004188.png (stored 0%)
# updating: data/train/cat/000309.png (stored 0%)
# updating: data/train/cat/002904.png (deflated 0%)
# updating: data/train/cat/000034.png (deflated 0%)
# updating: data/train/cat/000922.png (deflated 0%)
# updating: data/train/cat/004309.png (deflated 0%)
# updating: data/train/cat/001757.png (stored 0%)
# updating: data/train/cat/000684.png (deflated 0%)
# updating: data/train/cat/002102.png (stored 0%)
# updating: data/train/cat/002348.png (stored 0%)
# updating: data/train/cat/003195.png (stored 0%)
# updating: data/train/cat/000952.png (stored 0%)
# updating: data/train/cat/002714.png (stored 0%)
# updating: data/train/cat/002879.png (deflated 1%)
# updating: data/train/cat/000798.png (stored 0%)
# updating: data/train/cat/004476.png (deflated 0%)
# updating: data/train/cat/000377.png (deflated 0%)
# updating: data/train/cat/003864.png (deflated 0%)
# updating: data/train/cat/000759.png (deflated 0%)
# updating: data/train/cat/000493.png (stored 0%)
# updating: data/train/cat/000893.png (stored 0%)
# updating: data/train/cat/001927.png (stored 0%)
# updating: data/train/cat/002053.png (stored 0%)
# updating: data/train/cat/000621.png (deflated 0%)
# updating: data/train/cat/002768.png (deflated 0%)
# updating: data/train/cat/001328.png (stored 0%)
# updating: data/train/cat/004720.png (deflated 0%)
# updating: data/train/cat/001201.png (deflated 0%)
# updating: data/train/cat/001798.png (stored 0%)
# updating: data/train/cat/003775.png (deflated 0%)
# updating: data/train/cat/003034.png (deflated 1%)
# updating: data/train/cat/004577.png (stored 0%)
# updating: data/train/cat/003827.png (stored 0%)
# updating: data/train/cat/000406.png (deflated 0%)
# updating: data/train/cat/000599.png (stored 0%)
# updating: data/train/cat/003019.png (stored 0%)
# updating: data/train/cat/001146.png (stored 0%)
# updating: data/train/cat/001193.png (stored 0%)
# updating: data/train/cat/001896.png (deflated 0%)
# updating: data/train/cat/002702.png (deflated 0%)
# updating: data/train/cat/001724.png (deflated 0%)
# updating: data/train/cat/001817.png (deflated 0%)
# updating: data/train/cat/002461.png (stored 0%)
# updating: data/train/cat/002865.png (stored 0%)
# updating: data/train/cat/003956.png (deflated 0%)
# updating: data/train/cat/001119.png (stored 0%)
# updating: data/train/cat/002186.png (stored 0%)
# updating: data/train/cat/004341.png (deflated 0%)
# updating: data/train/cat/002055.png (deflated 0%)
# updating: data/train/cat/003071.png (stored 0%)
# updating: data/train/cat/004182.png (stored 0%)
# updating: data/train/cat/002172.png (stored 0%)
# updating: data/train/cat/001976.png (deflated 0%)
# updating: data/train/cat/001864.png (deflated 0%)
# updating: data/train/cat/000169.png (deflated 0%)
# updating: data/train/cat/004949.png (stored 0%)
# updating: data/train/cat/000663.png (stored 0%)
# updating: data/train/cat/000302.png (stored 0%)
# updating: data/train/cat/001269.png (stored 0%)
# updating: data/train/cat/001291.png (deflated 0%)
# updating: data/train/cat/001008.png (deflated 1%)
# updating: data/train/cat/004159.png (stored 0%)
# updating: data/train/cat/004873.png (stored 0%)
# updating: data/train/cat/003124.png (stored 0%)
# updating: data/train/cat/001971.png (stored 0%)
# updating: data/train/cat/000902.png (deflated 0%)
# updating: data/train/cat/001137.png (stored 0%)
# updating: data/train/cat/000046.png (deflated 0%)
# updating: data/train/cat/002468.png (deflated 0%)
# updating: data/train/cat/001156.png (stored 0%)
# updating: data/train/cat/002330.png (stored 0%)
# updating: data/train/cat/004817.png (stored 0%)
# updating: data/train/cat/003497.png (stored 0%)
# updating: data/train/cat/001043.png (stored 0%)
# updating: data/train/cat/001245.png (deflated 0%)
# updating: data/train/cat/000110.png (stored 0%)
# updating: data/train/cat/000506.png (deflated 0%)
# updating: data/train/cat/003172.png (deflated 0%)
# updating: data/train/cat/001338.png (stored 0%)
# updating: data/train/cat/001660.png (stored 0%)
# updating: data/train/cat/003108.png (stored 0%)
# updating: data/train/cat/002696.png (stored 0%)
# updating: data/train/cat/000325.png (stored 0%)
# updating: data/train/cat/002138.png (deflated 1%)
# updating: data/train/cat/001906.png (stored 0%)
# updating: data/train/cat/001955.png (deflated 0%)
# updating: data/train/cat/000517.png (stored 0%)
# updating: data/train/cat/003120.png (stored 0%)
# updating: data/train/cat/003810.png (deflated 0%)
# updating: data/train/cat/001985.png (deflated 0%)
# updating: data/train/cat/003428.png (deflated 0%)
# updating: data/train/cat/002647.png (stored 0%)
# updating: data/train/cat/002644.png (stored 0%)
# updating: data/train/cat/001257.png (stored 0%)
# updating: data/train/cat/001636.png (stored 0%)
# updating: data/train/cat/001233.png (deflated 0%)
# updating: data/train/cat/001101.png (stored 0%)
# updating: data/train/cat/002864.png (stored 0%)
# updating: data/train/cat/000583.png (stored 0%)
# updating: data/train/cat/004214.png (stored 0%)
# updating: data/train/cat/000584.png (stored 0%)
# updating: data/train/cat/001675.png (stored 0%)
# updating: data/train/cat/002717.png (deflated 0%)
# updating: data/train/cat/002487.png (stored 0%)
# updating: data/train/cat/004983.png (deflated 0%)
# updating: data/train/cat/002073.png (deflated 0%)
# updating: data/train/cat/002469.png (stored 0%)
# updating: data/train/cat/002349.png (stored 0%)
# updating: data/train/cat/002344.png (deflated 0%)
# updating: data/train/cat/003596.png (stored 0%)
# updating: data/train/cat/004271.png (stored 0%)
# updating: data/train/cat/001078.png (stored 0%)
# updating: data/train/cat/001870.png (stored 0%)
# updating: data/train/cat/000597.png (stored 0%)
# updating: data/train/cat/001095.png (deflated 0%)
# updating: data/train/cat/000594.png (stored 0%)
# updating: data/train/cat/001960.png (deflated 1%)
# updating: data/train/cat/001028.png (deflated 0%)
# updating: data/train/cat/001923.png (stored 0%)
# updating: data/train/cat/004594.png (deflated 0%)
# updating: data/train/cat/000728.png (deflated 0%)
# updating: data/train/cat/000349.png (deflated 0%)
# updating: data/train/cat/003091.png (deflated 0%)
# updating: data/train/cat/004516.png (deflated 0%)
# updating: data/train/cat/001154.png (stored 0%)
# updating: data/train/cat/002680.png (stored 0%)
# updating: data/train/cat/003861.png (deflated 0%)
# updating: data/train/cat/003606.png (stored 0%)
# updating: data/train/cat/003203.png (deflated 0%)
# updating: data/train/cat/000129.png (stored 0%)
# updating: data/train/cat/004801.png (stored 0%)
# updating: data/train/cat/004497.png (deflated 0%)
# updating: data/train/cat/004261.png (stored 0%)
# updating: data/train/cat/002514.png (deflated 0%)
# updating: data/train/cat/000832.png (stored 0%)
# updating: data/train/cat/000532.png (stored 0%)
# updating: data/train/cat/000056.png (deflated 2%)
# updating: data/train/cat/000133.png (stored 0%)
# updating: data/train/cat/001517.png (stored 0%)
# updating: data/train/cat/001266.png (stored 0%)
# updating: data/train/cat/004736.png (stored 0%)
# updating: data/train/cat/001954.png (deflated 0%)
# updating: data/train/cat/001732.png (deflated 1%)
# updating: data/train/cat/000462.png (stored 0%)
# updating: data/train/cat/001876.png (deflated 0%)
# updating: data/train/cat/002484.png (stored 0%)
# updating: data/train/cat/004463.png (stored 0%)
# updating: data/train/cat/004656.png (deflated 0%)
# updating: data/train/cat/003959.png (deflated 0%)
# updating: data/train/cat/002462.png (deflated 0%)
# updating: data/train/cat/004243.png (stored 0%)
# updating: data/train/cat/002568.png (stored 0%)
# updating: data/train/cat/000089.png (stored 0%)
# updating: data/train/cat/002494.png (deflated 1%)
# updating: data/train/cat/000290.png (deflated 0%)
# updating: data/train/cat/004933.png (deflated 0%)
# updating: data/train/cat/003992.png (stored 0%)
# updating: data/train/cat/000808.png (stored 0%)
# updating: data/train/cat/004940.png (deflated 0%)
# updating: data/train/cat/003745.png (deflated 0%)
# updating: data/train/cat/001462.png (deflated 1%)
# updating: data/train/cat/002141.png (deflated 1%)
# updating: data/train/cat/004400.png (stored 0%)
# updating: data/train/cat/001077.png (stored 0%)
# updating: data/train/cat/004423.png (deflated 0%)
# updating: data/train/cat/003776.png (stored 0%)
# updating: data/train/cat/004840.png (stored 0%)
# updating: data/train/cat/001001.png (stored 0%)
# updating: data/train/cat/003946.png (stored 0%)
# updating: data/train/cat/000638.png (deflated 0%)
# updating: data/train/cat/003169.png (deflated 0%)
# updating: data/train/cat/002267.png (deflated 0%)
# updating: data/train/cat/003246.png (deflated 2%)
# updating: data/train/airplane/ (stored 0%)
# updating: data/train/airplane/004389.png (stored 0%)
# updating: data/train/airplane/002909.png (stored 0%)
# updating: data/train/airplane/002531.png (stored 0%)
# updating: data/train/airplane/000344.png (stored 0%)
# updating: data/train/airplane/000885.png (stored 0%)
# updating: data/train/airplane/003651.png (deflated 0%)
# updating: data/train/airplane/000825.png (stored 0%)
# updating: data/train/airplane/000203.png (stored 0%)
# updating: data/train/airplane/004526.png (stored 0%)
# updating: data/train/airplane/004917.png (stored 0%)
# updating: data/train/airplane/002496.png (stored 0%)
# updating: data/train/airplane/000030.png (stored 0%)
# updating: data/train/airplane/004270.png (stored 0%)
# updating: data/train/airplane/004395.png (stored 0%)
# updating: data/train/airplane/000081.png (deflated 0%)
# updating: data/train/airplane/003941.png (stored 0%)
# updating: data/train/airplane/002529.png (stored 0%)
# updating: data/train/airplane/003929.png (stored 0%)
# updating: data/train/airplane/000408.png (stored 0%)
# updating: data/train/airplane/003843.png (stored 0%)
# updating: data/train/airplane/000437.png (deflated 0%)
# updating: data/train/airplane/002677.png (stored 0%)
# updating: data/train/airplane/000522.png (stored 0%)
# updating: data/train/airplane/003608.png (deflated 0%)
# updating: data/train/airplane/003365.png (stored 0%)
# updating: data/train/airplane/001845.png (stored 0%)
# updating: data/train/airplane/004848.png (stored 0%)
# updating: data/train/airplane/003616.png (stored 0%)
# updating: data/train/airplane/004120.png (stored 0%)
# updating: data/train/airplane/004695.png (stored 0%)
# updating: data/train/airplane/004564.png (deflated 0%)
# updating: data/train/airplane/004567.png (stored 0%)
# updating: data/train/airplane/002934.png (stored 0%)
# updating: data/train/airplane/003552.png (stored 0%)
# updating: data/train/airplane/004890.png (stored 0%)
# updating: data/train/airplane/004155.png (stored 0%)
# updating: data/train/airplane/002892.png (stored 0%)
# updating: data/train/airplane/000592.png (stored 0%)
# updating: data/train/airplane/001451.png (stored 0%)
# updating: data/train/airplane/001222.png (stored 0%)
# updating: data/train/airplane/002422.png (stored 0%)
# updating: data/train/airplane/003110.png (stored 0%)
# updating: data/train/airplane/002365.png (stored 0%)
# updating: data/train/airplane/002000.png (stored 0%)
# updating: data/train/airplane/002450.png (deflated 0%)
# updating: data/train/airplane/002079.png (stored 0%)
# updating: data/train/airplane/000333.png (stored 0%)
# updating: data/train/airplane/003800.png (deflated 2%)
# updating: data/train/airplane/004222.png (stored 0%)
# updating: data/train/airplane/001136.png (stored 0%)
# updating: data/train/airplane/002119.png (stored 0%)
# updating: data/train/airplane/002932.png (stored 0%)
# updating: data/train/airplane/004043.png (stored 0%)
# updating: data/train/airplane/003506.png (stored 0%)
# updating: data/train/airplane/002375.png (stored 0%)
# updating: data/train/airplane/003092.png (stored 0%)
# updating: data/train/airplane/001117.png (stored 0%)
# updating: data/train/airplane/004283.png (stored 0%)
# updating: data/train/airplane/002719.png (stored 0%)
# updating: data/train/airplane/000736.png (stored 0%)
# updating: data/train/airplane/000574.png (stored 0%)
# updating: data/train/airplane/000998.png (stored 0%)
# updating: data/train/airplane/003479.png (stored 0%)
# updating: data/train/airplane/003038.png (stored 0%)
# updating: data/train/airplane/004723.png (stored 0%)
# updating: data/train/airplane/001623.png (deflated 0%)
# updating: data/train/airplane/000073.png (stored 0%)
# updating: data/train/airplane/000577.png (stored 0%)
# updating: data/train/airplane/001407.png (stored 0%)
# updating: data/train/airplane/004435.png (stored 0%)
# updating: data/train/airplane/002668.png (stored 0%)
# updating: data/train/airplane/004346.png (stored 0%)
# updating: data/train/airplane/004002.png (stored 0%)
# updating: data/train/airplane/001281.png (deflated 0%)
# updating: data/train/airplane/001477.png (stored 0%)
# updating: data/train/airplane/004386.png (stored 0%)
# updating: data/train/airplane/000779.png (stored 0%)
# updating: data/train/airplane/004512.png (stored 0%)
# updating: data/train/airplane/001805.png (deflated 1%)
# updating: data/train/airplane/003920.png (stored 0%)
# updating: data/train/airplane/003697.png (stored 0%)
# updating: data/train/airplane/001884.png (stored 0%)
# updating: data/train/airplane/000098.png (stored 0%)
# updating: data/train/airplane/003470.png (stored 0%)
# updating: data/train/airplane/002968.png (stored 0%)
# updating: data/train/airplane/004421.png (stored 0%)
# updating: data/train/airplane/000695.png (stored 0%)
# updating: data/train/airplane/002839.png (stored 0%)
# updating: data/train/airplane/003962.png (stored 0%)
# updating: data/train/airplane/004237.png (stored 0%)
# updating: data/train/airplane/002420.png (stored 0%)
# updating: data/train/airplane/004529.png (stored 0%)
# updating: data/train/airplane/003875.png (deflated 0%)
# updating: data/train/airplane/002161.png (stored 0%)
# updating: data/train/airplane/000183.png (stored 0%)
# updating: data/train/airplane/004781.png (stored 0%)
# updating: data/train/airplane/004470.png (stored 0%)
# updating: data/train/airplane/000236.png (stored 0%)
# updating: data/train/airplane/000894.png (stored 0%)
# updating: data/train/airplane/000676.png (stored 0%)
# updating: data/train/airplane/002635.png (stored 0%)
# updating: data/train/airplane/003356.png (stored 0%)
# updating: data/train/airplane/004150.png (stored 0%)
# updating: data/train/airplane/003113.png (stored 0%)
# updating: data/train/airplane/004238.png (deflated 1%)
# updating: data/train/airplane/003012.png (stored 0%)
# updating: data/train/airplane/002710.png (stored 0%)
# updating: data/train/airplane/003866.png (stored 0%)
# updating: data/train/airplane/003951.png (stored 0%)
# updating: data/train/airplane/003853.png (stored 0%)
# updating: data/train/airplane/000487.png (stored 0%)
# updating: data/train/airplane/001090.png (stored 0%)
# updating: data/train/airplane/002794.png (stored 0%)
# updating: data/train/airplane/000781.png (stored 0%)
# updating: data/train/airplane/004278.png (stored 0%)
# updating: data/train/airplane/004957.png (stored 0%)
# updating: data/train/airplane/000444.png (stored 0%)
# updating: data/train/airplane/004828.png (stored 0%)
# updating: data/train/airplane/003314.png (stored 0%)
# updating: data/train/airplane/000257.png (stored 0%)
# updating: data/train/airplane/001978.png (stored 0%)
# updating: data/train/airplane/002542.png (stored 0%)
# updating: data/train/airplane/003150.png (stored 0%)
# updating: data/train/airplane/003967.png (stored 0%)
# updating: data/train/airplane/000397.png (stored 0%)
# updating: data/train/airplane/001153.png (stored 0%)
# updating: data/train/airplane/000719.png (stored 0%)
# updating: data/train/airplane/002781.png (stored 0%)
# updating: data/train/airplane/001523.png (stored 0%)
# updating: data/train/airplane/002296.png (stored 0%)
# updating: data/train/airplane/000579.png (stored 0%)
# updating: data/train/airplane/002978.png (stored 0%)
# updating: data/train/airplane/002440.png (stored 0%)
# updating: data/train/airplane/001926.png (stored 0%)
# updating: data/train/airplane/000139.png (stored 0%)
# updating: data/train/airplane/002442.png (stored 0%)
# updating: data/train/airplane/003603.png (stored 0%)
# updating: data/train/airplane/002459.png (stored 0%)
# updating: data/train/airplane/000646.png (stored 0%)
# updating: data/train/airplane/001213.png (stored 0%)
# updating: data/train/airplane/000622.png (stored 0%)
# updating: data/train/airplane/001779.png (stored 0%)
# updating: data/train/airplane/004966.png (stored 0%)
# updating: data/train/airplane/001912.png (stored 0%)
# updating: data/train/airplane/003673.png (stored 0%)
# updating: data/train/airplane/002588.png (stored 0%)
# updating: data/train/airplane/002155.png (stored 0%)
# updating: data/train/airplane/001131.png (stored 0%)
# updating: data/train/airplane/003161.png (stored 0%)
# updating: data/train/airplane/001412.png (stored 0%)
# updating: data/train/airplane/002302.png (stored 0%)
# updating: data/train/airplane/000933.png (stored 0%)
# updating: data/train/airplane/003097.png (deflated 1%)
# updating: data/train/airplane/002094.png (stored 0%)
# updating: data/train/airplane/002434.png (stored 0%)
# updating: data/train/airplane/004299.png (stored 0%)
# updating: data/train/airplane/002910.png (stored 0%)
# updating: data/train/airplane/004384.png (stored 0%)
# updating: data/train/airplane/002100.png (stored 0%)
# updating: data/train/airplane/001713.png (stored 0%)
# updating: data/train/airplane/004041.png (deflated 1%)
# updating: data/train/airplane/004451.png (stored 0%)
# updating: data/train/airplane/002351.png (stored 0%)
# updating: data/train/airplane/003332.png (stored 0%)
# updating: data/train/airplane/004652.png (deflated 0%)
# updating: data/train/airplane/000241.png (stored 0%)
# updating: data/train/airplane/001382.png (stored 0%)
# updating: data/train/airplane/002791.png (stored 0%)
# updating: data/train/airplane/003736.png (stored 0%)
# updating: data/train/airplane/003588.png (stored 0%)
# updating: data/train/airplane/003436.png (stored 0%)
# updating: data/train/airplane/004483.png (stored 0%)
# updating: data/train/airplane/002755.png (stored 0%)
# updating: data/train/airplane/001055.png (stored 0%)
# updating: data/train/airplane/001731.png (stored 0%)
# updating: data/train/airplane/000733.png (stored 0%)
# updating: data/train/airplane/002033.png (stored 0%)
# updating: data/train/airplane/000590.png (deflated 0%)
# updating: data/train/airplane/004517.png (stored 0%)
# updating: data/train/airplane/001585.png (deflated 0%)
# updating: data/train/airplane/003840.png (stored 0%)
# updating: data/train/airplane/002276.png (stored 0%)
# updating: data/train/airplane/004448.png (stored 0%)
# updating: data/train/airplane/003432.png (stored 0%)
# updating: data/train/airplane/001920.png (stored 0%)
# updating: data/train/airplane/004245.png (stored 0%)
# updating: data/train/airplane/003577.png (stored 0%)
# updating: data/train/airplane/002246.png (stored 0%)
# updating: data/train/airplane/002723.png (stored 0%)
# updating: data/train/airplane/000643.png (stored 0%)
# updating: data/train/airplane/004419.png (stored 0%)
# updating: data/train/airplane/001841.png (stored 0%)
# updating: data/train/airplane/002132.png (stored 0%)
# updating: data/train/airplane/002237.png (stored 0%)
# updating: data/train/airplane/002610.png (stored 0%)
# updating: data/train/airplane/000012.png (deflated 0%)
# updating: data/train/airplane/002797.png (stored 0%)
# updating: data/train/airplane/003025.png (stored 0%)
# updating: data/train/airplane/003971.png (stored 0%)
# updating: data/train/airplane/002071.png (stored 0%)
# updating: data/train/airplane/001820.png (stored 0%)
# updating: data/train/airplane/000562.png (stored 0%)
# updating: data/train/airplane/002038.png (stored 0%)
# updating: data/train/airplane/004785.png (stored 0%)
# updating: data/train/airplane/001484.png (stored 0%)
# updating: data/train/airplane/001263.png (deflated 0%)
# updating: data/train/airplane/002166.png (stored 0%)
# updating: data/train/airplane/004653.png (stored 0%)
# updating: data/train/airplane/000343.png (stored 0%)
# updating: data/train/airplane/003765.png (stored 0%)
# updating: data/train/airplane/000975.png (stored 0%)
# updating: data/train/airplane/004454.png (stored 0%)
# updating: data/train/airplane/001998.png (stored 0%)
# updating: data/train/airplane/002076.png (stored 0%)
# updating: data/train/airplane/000300.png (stored 0%)
# updating: data/train/airplane/003438.png (deflated 0%)
# updating: data/train/airplane/000096.png (stored 0%)
# updating: data/train/airplane/003973.png (stored 0%)
# updating: data/train/airplane/003256.png (stored 0%)
# updating: data/train/airplane/004133.png (stored 0%)
# updating: data/train/airplane/004255.png (deflated 0%)
# updating: data/train/airplane/001106.png (stored 0%)
# updating: data/train/airplane/000296.png (stored 0%)
# updating: data/train/airplane/003181.png (stored 0%)
# updating: data/train/airplane/003284.png (stored 0%)
# updating: data/train/airplane/000615.png (stored 0%)
# updating: data/train/airplane/002196.png (stored 0%)
# updating: data/train/airplane/003652.png (stored 0%)
# updating: data/train/airplane/003081.png (stored 0%)
# updating: data/train/airplane/001182.png (stored 0%)
# updating: data/train/airplane/001620.png (stored 0%)
# updating: data/train/airplane/000558.png (stored 0%)
# updating: data/train/airplane/001576.png (deflated 0%)
# updating: data/train/airplane/003024.png (deflated 0%)
# updating: data/train/airplane/002199.png (stored 0%)
# updating: data/train/airplane/002590.png (stored 0%)
# updating: data/train/airplane/004215.png (stored 0%)
# updating: data/train/airplane/002817.png (stored 0%)
# updating: data/train/airplane/004945.png (stored 0%)
# updating: data/train/airplane/003615.png (stored 0%)
# updating: data/train/airplane/001894.png (stored 0%)
# updating: data/train/airplane/003509.png (stored 0%)
# updating: data/train/airplane/003693.png (deflated 0%)
# updating: data/train/airplane/000354.png (stored 0%)
# updating: data/train/airplane/001237.png (stored 0%)
# updating: data/train/airplane/000262.png (stored 0%)
# updating: data/train/airplane/003447.png (stored 0%)
# updating: data/train/airplane/000938.png (stored 0%)
# updating: data/train/airplane/003125.png (stored 0%)
# updating: data/train/airplane/001403.png (stored 0%)
# updating: data/train/airplane/004523.png (stored 0%)
# updating: data/train/airplane/004013.png (stored 0%)
# updating: data/train/airplane/000606.png (stored 0%)
# updating: data/train/airplane/003341.png (stored 0%)
# updating: data/train/airplane/003056.png (stored 0%)
# updating: data/train/airplane/003280.png (stored 0%)
# updating: data/train/airplane/003682.png (stored 0%)
# updating: data/train/airplane/001609.png (stored 0%)
# updating: data/train/airplane/002695.png (stored 0%)
# updating: data/train/airplane/002682.png (stored 0%)
# updating: data/train/airplane/001215.png (stored 0%)
# updating: data/train/airplane/002481.png (stored 0%)
# updating: data/train/airplane/001588.png (deflated 0%)
# updating: data/train/airplane/002380.png (stored 0%)
# updating: data/train/airplane/000106.png (stored 0%)
# updating: data/train/airplane/001627.png (stored 0%)
# updating: data/train/airplane/004165.png (stored 0%)
# updating: data/train/airplane/003859.png (stored 0%)
# updating: data/train/airplane/002918.png (stored 0%)
# updating: data/train/airplane/001963.png (stored 0%)
# updating: data/train/airplane/002015.png (stored 0%)
# updating: data/train/airplane/003395.png (stored 0%)
# updating: data/train/airplane/003482.png (stored 0%)
# updating: data/train/airplane/000391.png (stored 0%)
# updating: data/train/airplane/001170.png (deflated 0%)
# updating: data/train/airplane/001452.png (stored 0%)
# updating: data/train/airplane/000206.png (deflated 0%)
# updating: data/train/airplane/002040.png (stored 0%)
# updating: data/train/airplane/001638.png (stored 0%)
# updating: data/train/airplane/001994.png (stored 0%)
# updating: data/train/airplane/001056.png (stored 0%)
# updating: data/train/airplane/003219.png (stored 0%)
# updating: data/train/airplane/003233.png (stored 0%)
# updating: data/train/airplane/004352.png (stored 0%)
# updating: data/train/airplane/000997.png (stored 0%)
# updating: data/train/airplane/003413.png (stored 0%)
# updating: data/train/airplane/003589.png (stored 0%)
# updating: data/train/airplane/002345.png (stored 0%)
# updating: data/train/airplane/003739.png (stored 0%)
# updating: data/train/airplane/004833.png (stored 0%)
# updating: data/train/airplane/000324.png (stored 0%)
# updating: data/train/airplane/002215.png (stored 0%)
# updating: data/train/airplane/000686.png (stored 0%)
# updating: data/train/airplane/004360.png (stored 0%)
# updating: data/train/airplane/004632.png (stored 0%)
# updating: data/train/airplane/004786.png (stored 0%)
# updating: data/train/airplane/004379.png (stored 0%)
# updating: data/train/airplane/001581.png (stored 0%)
# updating: data/train/airplane/004552.png (stored 0%)
# updating: data/train/airplane/004375.png (stored 0%)
# updating: data/train/airplane/003947.png (stored 0%)
# updating: data/train/airplane/001671.png (stored 0%)
# updating: data/train/airplane/001490.png (stored 0%)
# updating: data/train/airplane/002140.png (deflated 0%)
# updating: data/train/airplane/000031.png (stored 0%)
# updating: data/train/airplane/004797.png (deflated 0%)
# updating: data/train/airplane/000963.png (stored 0%)
# updating: data/train/airplane/000348.png (stored 0%)
# updating: data/train/airplane/002054.png (stored 0%)
# updating: data/train/airplane/004872.png (stored 0%)
# updating: data/train/airplane/002252.png (stored 0%)
# updating: data/train/airplane/002026.png (deflated 0%)
# updating: data/train/airplane/000748.png (stored 0%)
# updating: data/train/airplane/001608.png (stored 0%)
# updating: data/train/airplane/002245.png (stored 0%)
# updating: data/train/airplane/000814.png (stored 0%)
# updating: data/train/airplane/002572.png (stored 0%)
# updating: data/train/airplane/000708.png (stored 0%)
# updating: data/train/airplane/003373.png (stored 0%)
# updating: data/train/airplane/003822.png (deflated 0%)
# updating: data/train/airplane/002562.png (stored 0%)
# updating: data/train/airplane/003424.png (stored 0%)
# updating: data/train/airplane/002056.png (stored 0%)
# updating: data/train/airplane/001653.png (stored 0%)
# updating: data/train/airplane/000119.png (stored 0%)
# updating: data/train/airplane/000689.png (stored 0%)
# updating: data/train/airplane/004779.png (stored 0%)
# updating: data/train/airplane/004760.png (stored 0%)
# updating: data/train/airplane/001012.png (stored 0%)
# updating: data/train/airplane/001267.png (stored 0%)
# updating: data/train/airplane/003061.png (stored 0%)
# updating: data/train/airplane/002387.png (stored 0%)
# updating: data/train/airplane/002479.png (deflated 0%)
# updating: data/train/airplane/001766.png (stored 0%)
# updating: data/train/airplane/004968.png (stored 0%)
# updating: data/train/airplane/003849.png (stored 0%)
# updating: data/train/airplane/004837.png (stored 0%)
# updating: data/train/airplane/001006.png (stored 0%)
# updating: data/train/airplane/001891.png (deflated 0%)
# updating: data/train/airplane/000103.png (stored 0%)
# updating: data/train/airplane/001089.png (deflated 0%)
# updating: data/train/airplane/003848.png (stored 0%)
# updating: data/train/airplane/000053.png (stored 0%)
# updating: data/train/airplane/000911.png (stored 0%)
# updating: data/train/airplane/001754.png (stored 0%)
# updating: data/train/airplane/003058.png (stored 0%)
# updating: data/train/airplane/001332.png (stored 0%)
# updating: data/train/airplane/003128.png (stored 0%)
# updating: data/train/airplane/000200.png (stored 0%)
# updating: data/train/airplane/004753.png (deflated 0%)
# updating: data/train/airplane/002333.png (stored 0%)
# updating: data/train/airplane/002451.png (stored 0%)
# updating: data/train/airplane/000246.png (stored 0%)
# updating: data/train/airplane/003234.png (stored 0%)
# updating: data/train/airplane/003469.png (stored 0%)
# updating: data/train/airplane/001583.png (stored 0%)
# updating: data/train/airplane/004310.png (stored 0%)
# updating: data/train/airplane/003986.png (stored 0%)
# updating: data/train/airplane/004385.png (stored 0%)
# updating: data/train/airplane/000466.png (stored 0%)
# updating: data/train/airplane/001449.png (stored 0%)
# updating: data/train/airplane/000047.png (stored 0%)
# updating: data/train/airplane/002396.png (stored 0%)
# updating: data/train/airplane/002819.png (stored 0%)
# updating: data/train/airplane/002953.png (stored 0%)
# updating: data/train/airplane/000460.png (stored 0%)
# updating: data/train/airplane/003297.png (deflated 0%)
# updating: data/train/airplane/004378.png (stored 0%)
# updating: data/train/airplane/000340.png (stored 0%)
# updating: data/train/airplane/002047.png (stored 0%)
# updating: data/train/airplane/000768.png (stored 0%)
# updating: data/train/airplane/001152.png (stored 0%)
# updating: data/train/airplane/000071.png (stored 0%)
# updating: data/train/airplane/000032.png (stored 0%)
# updating: data/train/airplane/001030.png (stored 0%)
# updating: data/train/airplane/000999.png (stored 0%)
# updating: data/train/airplane/003852.png (stored 0%)
# updating: data/train/airplane/003259.png (stored 0%)
# updating: data/train/airplane/002113.png (stored 0%)
# updating: data/train/airplane/000328.png (stored 0%)
# updating: data/train/airplane/000694.png (stored 0%)
# updating: data/train/airplane/000104.png (stored 0%)
# updating: data/train/airplane/004003.png (stored 0%)
# updating: data/train/airplane/003228.png (stored 0%)
# updating: data/train/airplane/002609.png (stored 0%)
# updating: data/train/airplane/004345.png (stored 0%)
# updating: data/train/airplane/002679.png (stored 0%)
# updating: data/train/airplane/004037.png (stored 0%)
# updating: data/train/airplane/000152.png (stored 0%)
# updating: data/train/airplane/001809.png (stored 0%)
# updating: data/train/airplane/004118.png (stored 0%)
# updating: data/train/airplane/004330.png (stored 0%)
# updating: data/train/airplane/001278.png (deflated 0%)
# updating: data/train/airplane/000651.png (stored 0%)
# updating: data/train/airplane/004573.png (stored 0%)
# updating: data/train/airplane/001869.png (stored 0%)
# updating: data/train/airplane/000124.png (stored 0%)
# updating: data/train/airplane/004854.png (stored 0%)
# updating: data/train/airplane/003681.png (stored 0%)
# updating: data/train/airplane/000631.png (stored 0%)
# updating: data/train/horse/ (stored 0%)
# updating: data/train/horse/003557.png (deflated 0%)
# updating: data/train/horse/002117.png (stored 0%)
# updating: data/train/horse/001648.png (stored 0%)
# updating: data/train/horse/001164.png (stored 0%)
# updating: data/train/horse/001773.png (stored 0%)
# updating: data/train/horse/002564.png (stored 0%)
# updating: data/train/horse/003408.png (stored 0%)
# updating: data/train/horse/000862.png (stored 0%)
# updating: data/train/horse/004975.png (deflated 0%)
# updating: data/train/horse/000845.png (stored 0%)
# updating: data/train/horse/001628.png (stored 0%)
# updating: data/train/horse/004156.png (deflated 1%)
# updating: data/train/horse/003645.png (deflated 0%)
# updating: data/train/horse/002283.png (stored 0%)
# updating: data/train/horse/001964.png (stored 0%)
# updating: data/train/horse/002294.png (stored 0%)
# updating: data/train/horse/000385.png (stored 0%)
# updating: data/train/horse/000605.png (stored 0%)
# updating: data/train/horse/003856.png (deflated 0%)
# updating: data/train/horse/004487.png (stored 0%)
# updating: data/train/horse/001417.png (stored 0%)
# updating: data/train/horse/002913.png (stored 0%)
# updating: data/train/horse/004296.png (stored 0%)
# updating: data/train/horse/002733.png (stored 0%)
# updating: data/train/horse/001129.png (deflated 0%)
# updating: data/train/horse/003320.png (stored 0%)
# updating: data/train/horse/004178.png (stored 0%)
# updating: data/train/horse/004518.png (stored 0%)
# updating: data/train/horse/004547.png (stored 0%)
# updating: data/train/horse/001309.png (deflated 0%)
# updating: data/train/horse/002597.png (stored 0%)
# updating: data/train/horse/003702.png (stored 0%)
# updating: data/train/horse/002874.png (stored 0%)
# updating: data/train/horse/003204.png (stored 0%)
# updating: data/train/horse/002083.png (stored 0%)
# updating: data/train/horse/000589.png (stored 0%)
# updating: data/train/horse/004340.png (stored 0%)
# updating: data/train/horse/003958.png (stored 0%)
# updating: data/train/horse/001701.png (stored 0%)
# updating: data/train/horse/003313.png (stored 0%)
# updating: data/train/horse/003086.png (deflated 0%)
# updating: data/train/horse/003830.png (stored 0%)
# updating: data/train/horse/004908.png (stored 0%)
# updating: data/train/horse/003628.png (stored 0%)
# updating: data/train/horse/001301.png (stored 0%)
# updating: data/train/horse/001376.png (stored 0%)
# updating: data/train/horse/003812.png (stored 0%)
# updating: data/train/horse/000093.png (stored 0%)
# updating: data/train/horse/004033.png (stored 0%)
# updating: data/train/horse/000870.png (deflated 0%)
# updating: data/train/horse/002560.png (stored 0%)
# updating: data/train/horse/001177.png (stored 0%)
# updating: data/train/horse/002241.png (stored 0%)
# updating: data/train/horse/004602.png (stored 0%)
# updating: data/train/horse/002577.png (stored 0%)
# updating: data/train/horse/000873.png (stored 0%)
# updating: data/train/horse/003458.png (stored 0%)
# updating: data/train/horse/001556.png (deflated 0%)
# updating: data/train/horse/000189.png (deflated 0%)
# updating: data/train/horse/003972.png (stored 0%)
# updating: data/train/horse/001367.png (stored 0%)
# updating: data/train/horse/003488.png (stored 0%)
# updating: data/train/horse/000461.png (stored 0%)
# updating: data/train/horse/001566.png (stored 0%)
# updating: data/train/horse/002286.png (stored 0%)
# updating: data/train/horse/003308.png (stored 0%)
# updating: data/train/horse/001663.png (stored 0%)
# updating: data/train/horse/002763.png (stored 0%)
# updating: data/train/horse/000475.png (stored 0%)
# updating: data/train/horse/001058.png (stored 0%)
# updating: data/train/horse/004537.png (deflated 0%)
# updating: data/train/horse/000547.png (deflated 0%)
# updating: data/train/horse/001282.png (deflated 0%)
# updating: data/train/horse/000174.png (stored 0%)
# updating: data/train/horse/003103.png (stored 0%)
# updating: data/train/horse/000212.png (stored 0%)
# updating: data/train/horse/001711.png (stored 0%)
# updating: data/train/horse/002332.png (deflated 0%)
# updating: data/train/horse/000275.png (stored 0%)
# updating: data/train/horse/000642.png (deflated 0%)
# updating: data/train/horse/003362.png (stored 0%)
# updating: data/train/horse/000943.png (stored 0%)
# updating: data/train/horse/001276.png (stored 0%)
# updating: data/train/horse/002997.png (stored 0%)
# updating: data/train/horse/002357.png (stored 0%)
# updating: data/train/horse/002785.png (deflated 0%)
# updating: data/train/horse/003700.png (stored 0%)
# updating: data/train/horse/003571.png (deflated 0%)
# updating: data/train/horse/003055.png (stored 0%)
# updating: data/train/horse/004038.png (stored 0%)
# updating: data/train/horse/000465.png (deflated 0%)
# updating: data/train/horse/002092.png (stored 0%)
# updating: data/train/horse/001956.png (stored 0%)
# updating: data/train/horse/004019.png (deflated 0%)
# updating: data/train/horse/003723.png (stored 0%)
# updating: data/train/horse/002662.png (deflated 0%)
# updating: data/train/horse/000271.png (stored 0%)
# updating: data/train/horse/001096.png (stored 0%)
# updating: data/train/horse/000264.png (deflated 0%)
# updating: data/train/horse/001187.png (deflated 0%)
# updating: data/train/horse/002623.png (stored 0%)
# updating: data/train/horse/001935.png (stored 0%)
# updating: data/train/horse/004129.png (deflated 0%)
# updating: data/train/horse/002570.png (stored 0%)
# updating: data/train/horse/000092.png (stored 0%)
# updating: data/train/horse/000473.png (stored 0%)
# updating: data/train/horse/004353.png (stored 0%)
# updating: data/train/horse/001347.png (stored 0%)
# updating: data/train/horse/003708.png (deflated 0%)
# updating: data/train/horse/000463.png (deflated 0%)
# updating: data/train/horse/001433.png (stored 0%)
# updating: data/train/horse/002767.png (stored 0%)
# updating: data/train/horse/003149.png (stored 0%)
# updating: data/train/horse/001023.png (stored 0%)
# updating: data/train/horse/001979.png (stored 0%)
# updating: data/train/horse/000147.png (deflated 0%)
# updating: data/train/horse/003899.png (stored 0%)
# updating: data/train/horse/001810.png (stored 0%)
# updating: data/train/horse/003096.png (deflated 0%)
# updating: data/train/horse/004297.png (deflated 0%)
# updating: data/train/horse/001563.png (deflated 0%)
# updating: data/train/horse/002974.png (stored 0%)
# updating: data/train/horse/001123.png (deflated 0%)
# updating: data/train/horse/003909.png (stored 0%)
# updating: data/train/horse/002382.png (deflated 0%)
# updating: data/train/horse/004818.png (stored 0%)
# updating: data/train/horse/002589.png (stored 0%)
# updating: data/train/horse/004969.png (stored 0%)
# updating: data/train/horse/003781.png (stored 0%)
# updating: data/train/horse/004011.png (stored 0%)
# updating: data/train/horse/000238.png (stored 0%)
# updating: data/train/horse/002971.png (deflated 0%)
# updating: data/train/horse/001439.png (stored 0%)
# updating: data/train/horse/002850.png (stored 0%)
# updating: data/train/horse/003917.png (stored 0%)
# updating: data/train/horse/001434.png (stored 0%)
# updating: data/train/horse/000950.png (stored 0%)
# updating: data/train/horse/001498.png (stored 0%)
# updating: data/train/horse/003000.png (stored 0%)
# updating: data/train/horse/002219.png (stored 0%)
# updating: data/train/horse/004924.png (stored 0%)
# updating: data/train/horse/000895.png (stored 0%)
# updating: data/train/horse/003862.png (stored 0%)
# updating: data/train/horse/004766.png (stored 0%)
# updating: data/train/horse/002373.png (stored 0%)
# updating: data/train/horse/003520.png (stored 0%)
# updating: data/train/horse/004486.png (deflated 0%)
# updating: data/train/horse/001514.png (stored 0%)
# updating: data/train/horse/001812.png (stored 0%)
# updating: data/train/horse/001292.png (stored 0%)
# updating: data/train/horse/000632.png (stored 0%)
# updating: data/train/horse/003764.png (deflated 0%)
# updating: data/train/horse/001312.png (stored 0%)
# updating: data/train/horse/002871.png (stored 0%)
# updating: data/train/horse/002708.png (stored 0%)
# updating: data/train/horse/002177.png (stored 0%)
# updating: data/train/horse/003197.png (deflated 0%)
# updating: data/train/horse/002655.png (stored 0%)
# updating: data/train/horse/002425.png (deflated 0%)
# updating: data/train/horse/002187.png (stored 0%)
# updating: data/train/horse/000918.png (stored 0%)
# updating: data/train/horse/000128.png (stored 0%)
# updating: data/train/horse/002088.png (stored 0%)
# updating: data/train/horse/004816.png (deflated 0%)
# updating: data/train/horse/004525.png (stored 0%)
# updating: data/train/horse/004740.png (stored 0%)
# updating: data/train/horse/000743.png (stored 0%)
# ...
# updating: data/val/ship/000530.png (deflated 0%)
# updating: data/val/ship/000897.png (stored 0%)
# updating: data/val/ship/003144.png (deflated 0%)
# updating: data/val/ship/003707.png (stored 0%)
# updating: data/val/ship/000025.png (stored 0%)
# updating: data/val/ship/003114.png (stored 0%)
# updating: data/val/ship/004874.png (stored 0%)
# updating: data/val/ship/001378.png (stored 0%)
# updating: data/val/ship/000843.png (stored 0%)
# updating: data/val/ship/004588.png (stored 0%)
# updating: data/val/ship/000924.png (deflated 0%)
# updating: data/val/ship/002453.png (stored 0%)
# updating: data/val/ship/001261.png (deflated 0%)
# updating: data/val/ship/004962.png (stored 0%)
# updating: data/val/ship/003818.png (stored 0%)
# updating: data/val/ship/003361.png (stored 0%)
# updating: data/val/ship/002489.png (deflated 0%)
# updating: data/val/ship/002078.png (stored 0%)
# updating: data/val/ship/003832.png (stored 0%)
# updating: data/val/ship/001306.png (stored 0%)
# updating: data/val/ship/001795.png (stored 0%)
# updating: data/val/ship/002090.png (stored 0%)
# updating: data/val/ship/004138.png (deflated 0%)
# updating: data/val/ship/003766.png (stored 0%)
# updating: data/val/ship/002298.png (stored 0%)
# updating: data/val/ship/003218.png (stored 0%)
# updating: data/val/ship/000088.png (stored 0%)
# updating: data/val/ship/002369.png (stored 0%)
# updating: data/val/ship/004459.png (stored 0%)
# updating: data/val/ship/004813.png (stored 0%)
# updating: data/val/ship/004858.png (deflated 0%)
# updating: data/val/ship/003944.png (stored 0%)
# updating: data/val/ship/001116.png (stored 0%)
# updating: data/val/ship/002836.png (stored 0%)
# updating: data/val/ship/000150.png (stored 0%)
# updating: data/val/ship/002159.png (stored 0%)
# updating: data/val/ship/001126.png (stored 0%)
# updating: data/val/ship/004192.png (stored 0%)
# updating: data/val/dog/ (stored 0%)
# updating: data/val/dog/004610.png (stored 0%)
# updating: data/val/dog/002353.png (stored 0%)
# updating: data/val/dog/000436.png (deflated 0%)
# updating: data/val/dog/002604.png (stored 0%)
# updating: data/val/dog/001421.png (stored 0%)
# updating: data/val/dog/002685.png (deflated 0%)
# updating: data/val/dog/002419.png (stored 0%)
# updating: data/val/dog/001360.png (stored 0%)
# updating: data/val/dog/001666.png (stored 0%)
# updating: data/val/dog/000215.png (deflated 2%)
# updating: data/val/dog/001690.png (deflated 0%)
# updating: data/val/dog/002477.png (stored 0%)
# updating: data/val/dog/003414.png (stored 0%)
# updating: data/val/dog/004321.png (stored 0%)
# updating: data/val/dog/000227.png (stored 0%)
# updating: data/val/dog/004637.png (stored 0%)
# updating: data/val/dog/001497.png (deflated 0%)
# updating: data/val/dog/003478.png (deflated 0%)
# updating: data/val/dog/001149.png (deflated 0%)
# updating: data/val/dog/004304.png (stored 0%)
# updating: data/val/dog/000365.png (deflated 0%)
# updating: data/val/dog/002417.png (deflated 0%)
# updating: data/val/dog/002860.png (stored 0%)
# updating: data/val/dog/003121.png (stored 0%)
# updating: data/val/dog/000867.png (stored 0%)
# updating: data/val/dog/004714.png (stored 0%)
# updating: data/val/dog/004782.png (deflated 0%)
# updating: data/val/dog/003490.png (deflated 0%)
# updating: data/val/dog/001635.png (deflated 0%)
# updating: data/val/dog/004717.png (stored 0%)
# updating: data/val/dog/004952.png (deflated 0%)
# updating: data/val/dog/002941.png (stored 0%)
# updating: data/val/dog/004524.png (stored 0%)
# updating: data/val/dog/004060.png (stored 0%)
# updating: data/val/dog/002732.png (stored 0%)
# updating: data/val/dog/002112.png (stored 0%)
# updating: data/val/dog/000228.png (stored 0%)
# updating: data/val/dog/002771.png (stored 0%)
# updating: data/val/dog/001598.png (stored 0%)
# updating: data/val/dog/002415.png (stored 0%)
# updating: data/val/dog/003059.png (deflated 0%)
# updating: data/val/dog/001024.png (stored 0%)
# updating: data/val/dog/003806.png (stored 0%)
# updating: data/val/dog/001863.png (deflated 0%)
# updating: data/val/dog/003173.png (stored 0%)
# updating: data/val/dog/004963.png (deflated 0%)
# updating: data/val/dog/002866.png (deflated 0%)
# updating: data/val/dog/003885.png (stored 0%)
# updating: data/val/dog/004759.png (stored 0%)
# updating: data/val/dog/004272.png (stored 0%)
# updating: data/val/dog/002670.png (deflated 0%)
# updating: data/val/dog/001674.png (deflated 0%)
# updating: data/val/dog/004832.png (deflated 0%)
# updating: data/val/dog/000329.png (stored 0%)
# updating: data/val/dog/002326.png (stored 0%)
# updating: data/val/dog/000828.png (stored 0%)
# updating: data/val/dog/002006.png (deflated 0%)
# updating: data/val/dog/004114.png (deflated 0%)
# updating: data/val/dog/002688.png (stored 0%)
# updating: data/val/dog/003301.png (deflated 0%)
# updating: data/val/dog/001921.png (stored 0%)
# updating: data/val/dog/002154.png (deflated 0%)
# updating: data/val/dog/003976.png (deflated 0%)
# updating: data/val/dog/001874.png (deflated 0%)
# updating: data/val/dog/000409.png (deflated 0%)
# updating: data/val/dog/002856.png (deflated 0%)
# updating: data/val/dog/000905.png (stored 0%)
# updating: data/val/dog/002569.png (stored 0%)
# updating: data/val/dog/004074.png (stored 0%)
# updating: data/val/dog/000495.png (stored 0%)
# updating: data/val/dog/004649.png (stored 0%)
# updating: data/val/dog/000892.png (deflated 0%)
# updating: data/val/dog/004001.png (stored 0%)
# updating: data/val/dog/002750.png (deflated 0%)
# updating: data/val/dog/002639.png (stored 0%)
# updating: data/val/dog/004907.png (stored 0%)
# updating: data/val/dog/004383.png (stored 0%)
# updating: data/val/dog/002444.png (stored 0%)
# updating: data/val/dog/002537.png (stored 0%)
# updating: data/val/dog/002221.png (stored 0%)
# updating: data/val/dog/001591.png (deflated 0%)
# updating: data/val/dog/001155.png (deflated 0%)
# updating: data/val/dog/003601.png (stored 0%)
# updating: data/val/dog/002976.png (stored 0%)
# updating: data/val/dog/001687.png (deflated 0%)
# updating: data/val/dog/000029.png (stored 0%)
# updating: data/val/dog/001677.png (stored 0%)
# updating: data/val/dog/000720.png (deflated 0%)
# updating: data/val/dog/000435.png (stored 0%)
# updating: data/val/dog/004533.png (deflated 0%)
# updating: data/val/dog/000028.png (stored 0%)
# updating: data/val/dog/001408.png (stored 0%)
# updating: data/val/dog/003965.png (stored 0%)
# updating: data/val/dog/004826.png (deflated 0%)
# updating: data/val/dog/002753.png (stored 0%)
# updating: data/val/dog/004905.png (deflated 0%)
# updating: data/val/dog/004906.png (deflated 0%)
# updating: data/val/dog/002956.png (stored 0%)
# updating: data/val/dog/004787.png (stored 0%)
# updating: data/val/dog/003327.png (stored 0%)
# updating: data/val/bird/ (stored 0%)
# updating: data/val/bird/002495.png (stored 0%)
# updating: data/val/bird/000614.png (stored 0%)
# updating: data/val/bird/004067.png (stored 0%)
# updating: data/val/bird/002731.png (stored 0%)
# updating: data/val/bird/003089.png (stored 0%)
# updating: data/val/bird/003016.png (stored 0%)
# updating: data/val/bird/001197.png (stored 0%)
# updating: data/val/bird/003363.png (stored 0%)
# updating: data/val/bird/004923.png (stored 0%)
# updating: data/val/bird/004570.png (stored 0%)
# updating: data/val/bird/002173.png (stored 0%)
# updating: data/val/bird/002413.png (stored 0%)
# updating: data/val/bird/003561.png (stored 0%)
# updating: data/val/bird/000459.png (stored 0%)
# updating: data/val/bird/004244.png (stored 0%)
# updating: data/val/bird/004280.png (stored 0%)
# updating: data/val/bird/000425.png (stored 0%)
# updating: data/val/bird/002987.png (stored 0%)
# updating: data/val/bird/000945.png (stored 0%)
# updating: data/val/bird/001459.png (deflated 0%)
# updating: data/val/bird/001474.png (stored 0%)
# updating: data/val/bird/004468.png (stored 0%)
# updating: data/val/bird/003352.png (stored 0%)
# updating: data/val/bird/000762.png (stored 0%)
# updating: data/val/bird/003099.png (stored 0%)
# updating: data/val/bird/001520.png (stored 0%)
# updating: data/val/bird/004361.png (stored 0%)
# updating: data/val/bird/004308.png (stored 0%)
# updating: data/val/bird/000912.png (deflated 0%)
# updating: data/val/bird/002858.png (deflated 0%)
# updating: data/val/bird/000000.png (stored 0%)
# updating: data/val/bird/002964.png (stored 0%)
# updating: data/val/bird/002946.png (stored 0%)
# updating: data/val/bird/004461.png (stored 0%)
# updating: data/val/bird/002743.png (stored 0%)
# updating: data/val/bird/000817.png (stored 0%)
# updating: data/val/bird/002066.png (stored 0%)
# updating: data/val/bird/004016.png (stored 0%)
# updating: data/val/bird/003326.png (stored 0%)
# updating: data/val/bird/000640.png (stored 0%)
# updating: data/val/bird/004557.png (stored 0%)
# updating: data/val/bird/000681.png (deflated 0%)
# updating: data/val/bird/002993.png (stored 0%)
# updating: data/val/bird/003797.png (stored 0%)
# updating: data/val/bird/001788.png (stored 0%)
# updating: data/val/bird/000021.png (stored 0%)
# updating: data/val/bird/004710.png (stored 0%)
# updating: data/val/bird/004690.png (stored 0%)
# updating: data/val/bird/001175.png (stored 0%)
# updating: data/val/bird/002456.png (stored 0%)
# updating: data/val/bird/001246.png (stored 0%)
# updating: data/val/bird/001305.png (stored 0%)
# updating: data/val/bird/002148.png (stored 0%)
# updating: data/val/bird/001577.png (stored 0%)
# updating: data/val/bird/003171.png (deflated 0%)
# updating: data/val/bird/001134.png (stored 0%)
# updating: data/val/bird/000421.png (stored 0%)
# updating: data/val/bird/000557.png (stored 0%)
# updating: data/val/bird/000649.png (deflated 1%)
# updating: data/val/bird/004194.png (stored 0%)
# updating: data/val/bird/000616.png (stored 0%)
# updating: data/val/bird/003208.png (stored 0%)
# updating: data/val/bird/000114.png (stored 0%)
# updating: data/val/bird/003143.png (stored 0%)
# updating: data/val/bird/004347.png (stored 0%)
# updating: data/val/bird/001777.png (stored 0%)
# updating: data/val/bird/004248.png (stored 0%)
# updating: data/val/bird/000641.png (deflated 0%)
# updating: data/val/bird/003358.png (stored 0%)
# updating: data/val/bird/000339.png (stored 0%)
# updating: data/val/bird/003729.png (stored 0%)
# updating: data/val/bird/001530.png (stored 0%)
# updating: data/val/bird/004273.png (stored 0%)
# updating: data/val/bird/003248.png (stored 0%)
# updating: data/val/bird/002013.png (stored 0%)
# updating: data/val/bird/000856.png (stored 0%)
# updating: data/val/bird/003004.png (stored 0%)
# updating: data/val/bird/000541.png (stored 0%)
# updating: data/val/bird/000223.png (stored 0%)
# updating: data/val/bird/001836.png (deflated 0%)
# updating: data/val/bird/004979.png (stored 0%)
# updating: data/val/bird/003625.png (stored 0%)
# updating: data/val/bird/003761.png (stored 0%)
# updating: data/val/bird/004048.png (stored 0%)
# updating: data/val/bird/004079.png (deflated 0%)
# updating: data/val/bird/002526.png (stored 0%)
# updating: data/val/bird/004107.png (stored 0%)
# updating: data/val/bird/004391.png (stored 0%)
# updating: data/val/bird/001350.png (stored 0%)
# updating: data/val/bird/003737.png (stored 0%)
# updating: data/val/bird/003303.png (stored 0%)
# updating: data/val/bird/002876.png (stored 0%)
# updating: data/val/bird/000335.png (stored 0%)
# updating: data/val/bird/002126.png (stored 0%)
# updating: data/val/bird/000664.png (deflated 1%)
# updating: data/val/bird/003404.png (stored 0%)
# updating: data/val/bird/000292.png (deflated 0%)
# updating: data/val/bird/000416.png (stored 0%)
# updating: data/val/bird/002224.png (stored 0%)
# updating: data/val/bird/003026.png (stored 0%)
# updating: data/val/car/ (stored 0%)
# updating: data/val/car/000418.png (stored 0%)
# updating: data/val/car/002519.png (stored 0%)
# updating: data/val/car/003201.png (stored 0%)
# updating: data/val/car/000732.png (deflated 0%)
# updating: data/val/car/004707.png (stored 0%)
# updating: data/val/car/001419.png (stored 0%)
# updating: data/val/car/001108.png (stored 0%)
# updating: data/val/car/000144.png (deflated 0%)
# updating: data/val/car/003077.png (deflated 0%)
# updating: data/val/car/004750.png (stored 0%)
# updating: data/val/car/004167.png (deflated 0%)
# updating: data/val/car/003912.png (stored 0%)
# updating: data/val/car/004856.png (deflated 0%)
# updating: data/val/car/000186.png (deflated 0%)
# updating: data/val/car/000595.png (stored 0%)
# updating: data/val/car/004153.png (stored 0%)
# updating: data/val/car/003511.png (deflated 0%)
# updating: data/val/car/003287.png (stored 0%)
# updating: data/val/car/003002.png (stored 0%)
# updating: data/val/car/001118.png (stored 0%)
# updating: data/val/car/002087.png (deflated 0%)
# updating: data/val/car/000332.png (deflated 0%)
# updating: data/val/car/002355.png (stored 0%)
# updating: data/val/car/002903.png (stored 0%)
# updating: data/val/car/001079.png (stored 0%)
# updating: data/val/car/003841.png (deflated 0%)
# updating: data/val/car/003592.png (stored 0%)
# updating: data/val/car/004715.png (stored 0%)
# updating: data/val/car/000770.png (stored 0%)
# updating: data/val/car/001113.png (deflated 0%)
# updating: data/val/car/000245.png (stored 0%)
# updating: data/val/car/003495.png (deflated 0%)
# updating: data/val/car/003829.png (stored 0%)
# updating: data/val/car/000161.png (deflated 0%)
# updating: data/val/car/002238.png (stored 0%)
# updating: data/val/car/001946.png (deflated 0%)
# updating: data/val/car/004057.png (stored 0%)
# updating: data/val/car/004898.png (deflated 0%)
# updating: data/val/car/000591.png (stored 0%)
# updating: data/val/car/002220.png (stored 0%)
# updating: data/val/car/000548.png (stored 0%)
# updating: data/val/car/003381.png (deflated 0%)
# updating: data/val/car/004053.png (stored 0%)
# updating: data/val/car/000286.png (deflated 0%)
# updating: data/val/car/002891.png (stored 0%)
# updating: data/val/car/004765.png (deflated 0%)
# updating: data/val/car/004177.png (stored 0%)
# updating: data/val/car/001341.png (stored 0%)
# updating: data/val/car/003068.png (deflated 0%)
# updating: data/val/car/003900.png (stored 0%)
# updating: data/val/car/003383.png (stored 0%)
# updating: data/val/car/003421.png (stored 0%)
# updating: data/val/car/003568.png (stored 0%)
# updating: data/val/car/001833.png (stored 0%)
# updating: data/val/car/004337.png (stored 0%)
# updating: data/val/car/003534.png (stored 0%)
# updating: data/val/car/000786.png (stored 0%)
# updating: data/val/car/001748.png (deflated 0%)
# updating: data/val/car/000509.png (stored 0%)
# updating: data/val/car/002835.png (stored 0%)
# updating: data/val/car/002806.png (stored 0%)
# updating: data/val/car/001855.png (stored 0%)
# updating: data/val/car/002202.png (stored 0%)
# updating: data/val/car/003460.png (stored 0%)
# updating: data/val/car/001534.png (stored 0%)
# updating: data/val/car/003340.png (deflated 0%)
# updating: data/val/car/000767.png (stored 0%)
# updating: data/val/car/004044.png (stored 0%)
# updating: data/val/car/000427.png (deflated 0%)
# updating: data/val/car/001000.png (stored 0%)
# updating: data/val/car/003132.png (stored 0%)
# updating: data/val/car/002271.png (stored 0%)
# updating: data/val/car/004158.png (stored 0%)
# updating: data/val/car/002912.png (deflated 0%)
# updating: data/val/car/004113.png (stored 0%)
# updating: data/val/car/003485.png (deflated 0%)
# updating: data/val/car/001729.png (stored 0%)
# updating: data/val/car/001722.png (stored 0%)
# updating: data/val/car/001081.png (deflated 0%)
# updating: data/val/car/002280.png (stored 0%)
# updating: data/val/car/001932.png (stored 0%)
# updating: data/val/car/002764.png (stored 0%)
# updating: data/val/car/000564.png (stored 0%)
# updating: data/val/car/004314.png (deflated 0%)
# updating: data/val/car/004943.png (stored 0%)
# updating: data/val/car/004937.png (stored 0%)
# updating: data/val/car/000429.png (stored 0%)
# updating: data/val/car/004151.png (stored 0%)
# updating: data/val/car/004729.png (deflated 0%)
# updating: data/val/car/002319.png (stored 0%)
# updating: data/val/car/004939.png (deflated 0%)
# updating: data/val/car/000513.png (deflated 0%)
# updating: data/val/car/000197.png (stored 0%)
# updating: data/val/car/000468.png (stored 0%)
# updating: data/val/car/002799.png (stored 0%)
# updating: data/val/car/002192.png (deflated 0%)
# updating: data/val/car/003118.png (stored 0%)
# updating: data/val/car/003135.png (deflated 0%)
# updating: data/val/car/001916.png (stored 0%)
# updating: data/val/car/002043.png (stored 0%)

# %%
# !zip -r runs.zip ./runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/profiler_vit/ (stored 0%)
#   adding: runs/vit_20251229_042332/ (stored 0%)
#   adding: runs/vit_20251229_042332/events.out.tfevents.1766982212.9df43ca8e2d0.365.1 (deflated 88%)
#   adding: runs/cnn_20251229_041244/ (stored 0%)
#   adding: runs/cnn_20251229_041244/events.out.tfevents.1766981564.9df43ca8e2d0.365.0 (deflated 93%)
#   adding: runs/profiler_cnn/ (stored 0%)

# %%
# !zip -r traces.zip ./traces
# Out:
#   adding: traces/ (stored 0%)
#   adding: traces/profiler_stats_vit.txt (deflated 87%)
#   adding: traces/model_comparison.txt (deflated 72%)
#   adding: traces/profiler_trace_vit.json (deflated 92%)
#   adding: traces/profiler_comparison.txt (deflated 58%)
#   adding: traces/confusion_matrix_vit.png (deflated 15%)
#   adding: traces/metrics.csv (stored 0%)
#   adding: traces/profiler_trace_cnn.json (deflated 91%)
#   adding: traces/profiler_stats_cnn.txt (deflated 88%)
#   adding: traces/confusion_matrix_cnn.png (deflated 13%)
